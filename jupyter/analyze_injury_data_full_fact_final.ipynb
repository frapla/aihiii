# %%
import logging
import os
import sys
from itertools import product
from pathlib import Path
from typing import Dict, List, Optional

import IPython
import matplotlib
from seaborn._statistics import LetterValues
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pyarrow.parquet as pq
import seaborn as sns
import textalloc as ta
from tqdm import tqdm

NOTEBOOK_PATH: Path = Path(IPython.extract_module_locals()[1]["__vsc_ipynb_file__"])
PROJECT_DIR: Path = NOTEBOOK_PATH.parent.parent
sys.path.append(str(PROJECT_DIR))
import src.utils.custom_log as custom_log
from src._StandardNames import StandardNames
from src.load.LoadForClassification import RENAMER, LoadForClassification
from src.utils.PathChecker import PathChecker
from src.utils.set_rcparams import set_rcparams
import src.utils.json_util as json_util

os.chdir(PROJECT_DIR)
set_rcparams()

LOG: logging.Logger = logging.getLogger(__name__)
custom_log.init_logger(log_lvl=logging.INFO)
LOG.info("Log start, project directory is %s (exist: %s)", PROJECT_DIR, PROJECT_DIR.is_dir())

CHECK: PathChecker = PathChecker()
STR: StandardNames = StandardNames()

FIG_DIR: Path = CHECK.check_directory(PROJECT_DIR / "reports" / "figures", exit=False)
FIG_DIR /= NOTEBOOK_PATH.stem
FIG_DIR.mkdir(parents=True, exist_ok=True)
LOG.info("Figure directory is %s (exist: %s)", FIG_DIR, FIG_DIR.is_dir())

DATA_DIR: Path = CHECK.check_directory(PROJECT_DIR / "data" / "doe" / "doe_big_grid_20230922_154140", exit=False)
INJ_FPATH: Path = CHECK.check_file(DATA_DIR / "injury_criteria.parquet", exit=False)
CLASSES_FPATHS: Dict[int, Path] = {
    i: CHECK.check_file(DATA_DIR / f"injury_criteria_classes_{i}.parquet", exit=False) for i in (2, 3, 5, 7)
}
CHANNELS_FPATH: Path = CHECK.check_file(DATA_DIR / "channels.parquet", exit=False)
DOE_FPATH: Path = CHECK.check_file(DATA_DIR / "doe.parquet", exit=False)
SIMID2ID_FPATH: Path = CHECK.check_file(DATA_DIR / "sim_id_2_id.parquet", exit=False)
# Out:
# 2024-10-27 08:13:16,074     INFO  MainProcess  MainThread Log start, project directory is /root/py_projects/aihiii (exist: True)
# 2024-10-27 08:13:16,075     INFO  MainProcess  MainThread Directory '/root/py_projects/aihiii/reports/figures' exists
# 2024-10-27 08:13:16,076     INFO  MainProcess  MainThread Figure directory is /root/py_projects/aihiii/reports/figures/analyze_injury_data_full_fact_final (exist: True)
# 2024-10-27 08:13:16,077     INFO  MainProcess  MainThread Directory '/root/py_projects/aihiii/data/doe/doe_big_grid_20230922_154140' exists
# 2024-10-27 08:13:16,078     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_big_grid_20230922_154140/injury_criteria.parquet' exists
# 2024-10-27 08:13:16,078     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_big_grid_20230922_154140/injury_criteria_classes_2.parquet' exists
# 2024-10-27 08:13:16,079     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_big_grid_20230922_154140/injury_criteria_classes_3.parquet' exists
# 2024-10-27 08:13:16,080     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_big_grid_20230922_154140/injury_criteria_classes_5.parquet' exists
# 2024-10-27 08:13:16,080     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_big_grid_20230922_154140/injury_criteria_classes_7.parquet' exists
# 2024-10-27 08:13:16,081     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_big_grid_20230922_154140/channels.parquet' exists
# 2024-10-27 08:13:16,082     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_big_grid_20230922_154140/doe.parquet' exists
# 2024-10-27 08:13:16,082     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_big_grid_20230922_154140/sim_id_2_id.parquet' exists

# %%
INJURIES: List[str] = [
    "Head_HIC15",
    "Head_a3ms",
    "Neck_My_Extension",
    "Neck_Fz_Max_Tension",
    "Neck_Fx_Shear_Max",
    "Chest_a3ms",
    "Chest_Deflection",
    "Chest_VC",
    "Femur_Fz_Max_Compression",
]
INJ_NAMES: Dict[str, str] = {
    "Head_HIC15": "Head $\\text{HIC}_\\text{15}$",
    "Head_a3ms": "Head $\\text{a}_\\text{3ms}$",
    "Neck_My_Extension": "Neck $\\text{M}_{\\text{y, Extension}}$",
    "Neck_Fz_Max_Tension": "Neck $\\text{F}_{\\text{z, Tension}}$",
    "Neck_Fx_Shear_Max": "Neck $\\text{F}_{\\text{x, Shear}}$",
    "Chest_a3ms": "Chest $\\text{a}_\\text{3ms}$",
    "Chest_Deflection": "Chest Deflection",
    "Chest_VC": "Chest VC",
    "Femur_Fz_Max_Compression": "Femur $\\text{F}_{\\text{z, Compression}}$",
}
WIDTH = 448.13095 / 72

# %%
def save_fig(fig: matplotlib.figure.Figure, f_name: str) -> None:
    f_path = FIG_DIR / f_name
    fig.savefig(f_path.with_suffix(".pdf"), transparent=False)
    LOG.info("Saved figure to %s", f_path)
    plt.close(fig)

# %%
def single_box_and_rug(inj_val: str, perc: int, ax, drop_ids: Optional[Dict[int, List[int]]] = None):
    filters = [(STR.perc, "==", perc)]
    if drop_ids is not None:
        filters += [(STR.id, "not in", drop_ids[perc])]

    db: pd.DataFrame = pd.read_parquet(INJ_FPATH, columns=[inj_val], filters=tuple(filters))[inj_val].droplevel(STR.perc)


    # base plot
    sns.rugplot(x=db, ax=ax, height=0.05)
    sns.boxenplot(
        x=db,
        ax=ax,
        fill=False,
        color=".5",
        linecolor="#137",
        flier_kws={"s": 0.2},
    )

    # extreme outlier
    if drop_ids is None:
        q1, q3 = db.quantile([0.25, 0.75])
        iqr = q3 - q1
        db_extreme = db[db.le(q1 - 3 * iqr) | db.ge(q3 + 3 * iqr)]
        if len(db_extreme) > 0:
            ax.scatter(
                db_extreme,
                [0] * len(db_extreme),
                color="r",
                marker="x",
                s=0.7,
                alpha=0.5,
            )
        
        try:
            fliers = LetterValues(k_depth="tukey", outlier_prop=0.007, trust_alpha=0.05)(db.values)["fliers"]
            idx = pd.Index(db.values)
            idx = [int(db.index[idx.get_loc(x)]) for x in fliers]

            ta.allocate(
                    ax=ax,
                    y=[0] * len(fliers),
                    x=fliers,
                    text_list=idx,
                    y_scatter=[0] * len(fliers),
                    x_scatter=fliers,
                    min_distance=0.1,
                    linecolor="g",
                    linewidth=0.2,
                    textsize=5,
                    avoid_label_lines_overlap=True,
                )
        except:
            pass

# %%
def box_and_rug():
    percs = [5, 50, 95]
    inj_names = INJURIES

    fig_width: float = WIDTH
    fig_height: float = 1.35*WIDTH

    fig, ax = plt.subplots(
        nrows=len(inj_names),
        ncols=len(percs),
        layout="constrained",
        figsize=(fig_width, fig_height),
    )

    # plot
    versions = list(product(list(enumerate(inj_names)), list(enumerate(percs))))
    for (row, inj_val), (col, perc) in tqdm(versions):
        single_box_and_rug(inj_val=inj_val, perc=perc, ax=ax[row, col])
        ax[row, 0].set_ylabel(INJ_NAMES[inj_val])
        ax[row, col].set_xlabel("")
        ax[0, col].set_title(f"HIII {perc:02d} {'F' if perc == 5 else 'M'}")

    save_fig(fig=fig, f_name="injury_criteria_box_and_rug")


box_and_rug()
# Out:
# 100%|██████████| 27/27 [00:22<00:00,  1.21it/s]
# 2024-10-27 08:13:51,011     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:13:51,030     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:13:51,033     INFO  MainProcess  MainThread kern dropped
# 2024-10-27 08:13:51,034     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:13:51,036     INFO  MainProcess  MainThread FFTM dropped
# 2024-10-27 08:13:51,040     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:13:51,047     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:13:51,059     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 08:13:51,061     INFO  MainProcess  MainThread Added gid0 to subset
# 2024-10-27 08:13:51,061     INFO  MainProcess  MainThread Added first four glyphs to subset
# 2024-10-27 08:13:51,062     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 30 glyphs before
# 2024-10-27 08:13:51,064     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 08:13:51,067     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 08:13:51,076     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 30 glyphs after
# 2024-10-27 08:13:51,077     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 08:13:51,079     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 08:13:51,080     INFO  MainProcess  MainThread Closing glyph list over 'MATH': 30 glyphs before
# 2024-10-27 08:13:51,081     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 08:13:51,082     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 08:13:51,083     INFO  MainProcess  MainThread Closed glyph list over 'MATH': 30 glyphs after
# 2024-10-27 08:13:51,084     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 08:13:51,085     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 08:13:51,085     INFO  MainProcess  MainThread Closing glyph list over 'glyf': 30 glyphs before
# 2024-10-27 08:13:51,086     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 08:13:51,087     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 08:13:51,088     INFO  MainProcess  MainThread Closed glyph list over 'glyf': 30 glyphs after
# 2024-10-27 08:13:51,089     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 08:13:51,090     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 08:13:51,091     INFO  MainProcess  MainThread Retaining 30 glyphs
# 2024-10-27 08:13:51,093     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:13:51,094     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:13:51,095     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:13:51,098     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:13:51,107     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:13:51,112     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:13:51,113     INFO  MainProcess  MainThread fpgm subsetting not needed
# 2024-10-27 08:13:51,114     INFO  MainProcess  MainThread prep subsetting not needed
# 2024-10-27 08:13:51,115     INFO  MainProcess  MainThread cvt  subsetting not needed
# 2024-10-27 08:13:51,116     INFO  MainProcess  MainThread loca subsetting not needed
# 2024-10-27 08:13:51,117     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:13:51,118     INFO  MainProcess  MainThread gasp subsetting not needed
# 2024-10-27 08:13:51,119     INFO  MainProcess  MainThread MATH subsetted
# 2024-10-27 08:13:51,124     INFO  MainProcess  MainThread GDEF subsetted
# 2024-10-27 08:13:51,178     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:13:51,185     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:13:51,186     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:13:51,190     INFO  MainProcess  MainThread glyf subsetted
# 2024-10-27 08:13:51,191     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:13:51,193     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:13:51,195     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:13:51,196     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 08:13:51,197     INFO  MainProcess  MainThread GDEF pruned
# 2024-10-27 08:13:51,199     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:13:51,200     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:13:51,213     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:13:51,230     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:13:51,238     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:13:51,240     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:13:51,244     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:13:51,250     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:13:51,268     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:13:51,271     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:13:51,273     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 37 glyphs before
# 2024-10-27 08:13:51,274     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'M', 'N', 'V', 'a', 'c', 'd', 'e', 'eight', 'f', 'five', 'four', 'h', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'zero']
# 2024-10-27 08:13:51,276     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 51, 52, 55, 56, 57, 58, 63, 64, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 89, 97, 99, 101, 102, 104, 106, 107, 108, 110, 112, 122]
# 2024-10-27 08:13:51,278     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 43 glyphs after
# 2024-10-27 08:13:51,279     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'M', 'N', 'V', 'a', 'c', 'd', 'e', 'eight', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'h', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'zero']
# 2024-10-27 08:13:51,280     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 51, 52, 55, 56, 57, 58, 63, 64, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 89, 97, 99, 101, 102, 104, 106, 107, 108, 110, 112, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:13:51,281     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 43 glyphs before
# 2024-10-27 08:13:51,282     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'M', 'N', 'V', 'a', 'c', 'd', 'e', 'eight', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'h', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'zero']
# 2024-10-27 08:13:51,283     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 51, 52, 55, 56, 57, 58, 63, 64, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 89, 97, 99, 101, 102, 104, 106, 107, 108, 110, 112, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:13:51,296     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 43 glyphs after
# 2024-10-27 08:13:51,298     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'M', 'N', 'V', 'a', 'c', 'd', 'e', 'eight', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'h', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'zero']
# 2024-10-27 08:13:51,299     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 51, 52, 55, 56, 57, 58, 63, 64, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 89, 97, 99, 101, 102, 104, 106, 107, 108, 110, 112, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:13:51,300     INFO  MainProcess  MainThread Retaining 43 glyphs
# 2024-10-27 08:13:51,302     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:13:51,303     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:13:51,305     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:13:51,306     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:13:51,308     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:13:51,309     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:13:51,311     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:13:51,315     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:13:51,337     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:13:51,339     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:13:51,340     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:13:51,343     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:13:51,347     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:13:51,348     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:13:51,359     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:13:51,362     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:13:51,364     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:13:51,370     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:13:51,529     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_full_fact_final/injury_criteria_box_and_rug

# %%
def plot_selection(n_largest: int = 10):
    inj2channels = {
        "Chest_Deflection": ["03CHST0000OCCUDSXD"],
        "Femur_Fz_Max_Compression": ["03FEMRRI00OCCUFOZD", "03FEMRLE00OCCUFOZD"],
        "Femur_Fz_Max_Tension": ["03FEMRRI00OCCUFOZD", "03FEMRLE00OCCUFOZD"],
        "Femur_Fz_Max": ["03FEMRRI00OCCUFOZD", "03FEMRLE00OCCUFOZD"],
        "Head_HIC15": ["03HEAD0000OCCUACXD", "03HEAD0000OCCUACYD", "03HEAD0000OCCUACZD", "03HEAD0000OCCUACRD"],
        "Head_HIC36": ["03HEAD0000OCCUACXD", "03HEAD0000OCCUACYD", "03HEAD0000OCCUACZD", "03HEAD0000OCCUACRD"],
        "Head_a3ms": ["03HEAD0000OCCUACXD", "03HEAD0000OCCUACYD", "03HEAD0000OCCUACZD", "03HEAD0000OCCUACRD"],
        "Chest_a3ms": ["03CHST0000OCCUACXD", "03CHST0000OCCUACYD", "03CHST0000OCCUACZD", "03CHST0000OCCUACRD"],
        "Neck_Fx_Shear_Max": ["03NECKUP00OCCUFOXD"],
        "Neck_Fz_Max_Tension": ["03NECKUP00OCCUFOZD"],
        "Neck_Fz_Max_Compression": ["03NECKUP00OCCUFOZD"],
        "Neck_My_Max": ["03NECKUP00OCCUMOYD"],
        "Neck_My_Extension": ["03NECKUP00OCCUMOYD"],
        "Neck_Nij": ["03NECKUP00OCCUMOYD", "03NECKUP00OCCUFOZD"],
    }
    WIDTH
    percs = [5, 50, 95]
    inj_names = sorted(set(pq.read_table(INJ_FPATH).schema.names) - {STR.perc, STR.id})
    versions = list(product(inj_names, percs))
    for inj_name, perc in tqdm(versions):
        if inj_name not in INJ_NAMES or inj_name not in inj2channels:
            continue
        db: pd.DataFrame = pd.read_parquet(INJ_FPATH, columns=[inj_name], filters=[(STR.perc, "==", perc)])[inj_name]
        ids = db.nlargest(n_largest).index.get_level_values(STR.id).to_list()

        channel_data = pd.read_parquet(
            DATA_DIR / "channels.parquet",
            columns=inj2channels[inj_name],
            filters=[(STR.id, "in", ids), (STR.perc, "==", perc)],
        ).sort_values(by=STR.time)

        fig, ax = plt.subplot_mosaic(
            mosaic=[["distro"] * len(inj2channels[inj_name]), sorted(inj2channels[inj_name])],
            # sharex="row",
            # sharey="row",
            layout="constrained",
            figsize=(WIDTH, 0.6*WIDTH),
            height_ratios=[0.2, 0.8],
        )
        fig.suptitle(f"{INJ_NAMES[inj_name]} - HIII {perc:02d} {'F' if perc == 5 else 'M'}")
        single_box_and_rug(inj_val=inj_name, perc=perc, ax=ax["distro"])
        ax["distro"].set_xlabel("")
        for ch in inj2channels[inj_name]:
            for idx in ids:
                f = channel_data.loc[(slice(None), idx), ch]
                ax[ch].plot(f.index.get_level_values(STR.time), f, label=int(idx))
            ax[ch].grid()
            ax[ch].set_ylabel(ch)
            ax[ch].set_xlabel(STR.time)
        ax[inj2channels[inj_name][-1]].legend()
        save_fig(fig=fig, f_name=f"{inj_name}_HIII{perc:02d}_{n_largest}_largest_channels")


plot_selection()
# Out:
#   0%|          | 0/48 [00:00<?, ?it/s]2024-10-27 08:13:53,019     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:13:53,025     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:13:53,027     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:13:53,029     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:13:53,034     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:13:53,044     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:13:53,046     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:13:53,047     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 20 glyphs before
# 2024-10-27 08:13:53,048     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'c', 'e', 'f', 'five', 'h', 'hyphen', 'i', 'l', 'n', 'o', 's', 'space', 't', 'zero']
# 2024-10-27 08:13:53,049     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 44, 47, 51, 55, 56, 57, 63, 64, 65, 66, 67, 73, 78, 82, 99, 104, 106, 122]
# 2024-10-27 08:13:53,051     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 25 glyphs after
# 2024-10-27 08:13:53,052     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'five', 'h', 'hyphen', 'i', 'l', 'n', 'o', 's', 'space', 't', 'zero']
# 2024-10-27 08:13:53,053     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 44, 47, 51, 55, 56, 57, 63, 64, 65, 66, 67, 73, 78, 82, 99, 104, 106, 122, 123, 124, 125, 126, 127]
# 2024-10-27 08:13:53,053     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 25 glyphs before
# 2024-10-27 08:13:53,054     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'five', 'h', 'hyphen', 'i', 'l', 'n', 'o', 's', 'space', 't', 'zero']
# 2024-10-27 08:13:53,055     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 44, 47, 51, 55, 56, 57, 63, 64, 65, 66, 67, 73, 78, 82, 99, 104, 106, 122, 123, 124, 125, 126, 127]
# 2024-10-27 08:13:53,060     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 25 glyphs after
# 2024-10-27 08:13:53,062     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'five', 'h', 'hyphen', 'i', 'l', 'n', 'o', 's', 'space', 't', 'zero']
# 2024-10-27 08:13:53,064     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 44, 47, 51, 55, 56, 57, 63, 64, 65, 66, 67, 73, 78, 82, 99, 104, 106, 122, 123, 124, 125, 126, 127]
# 2024-10-27 08:13:53,066     INFO  MainProcess  MainThread Retaining 25 glyphs
# 2024-10-27 08:13:53,067     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:13:53,069     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08
INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 23 glyphs after
# 2024-10-27 08:13:56,662     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'H', 'I', 'M', 'O', 'S', 'T', 'U', 'X', 'eight', 'five', 'four', 'minus', 'nine', 'one', 'seven', 'six', 'three', 'two', 'zero']
# 2024-10-27 08:13:56,662     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 47, 50, 52, 57, 58, 63, 66, 75, 79, 81, 83, 98, 101, 102, 105, 107, 108, 109, 116, 122, 419]
# 2024-10-27 08:13:56,664     INFO  MainProcess  MainThread Retaining 23 glyphs
# 2024-10-27 08:13:56,665     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:13:56,666     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:13:56,666     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:13:56,667     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:13:56,669     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:13:56,670     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:13:56,671     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:13:56,677     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:13:56,696     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:13:56,698     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:13:56,699     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:13:56,700     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:13:56,704     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:13:56,706     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:13:56,710     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:13:56,711     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:13:56,713     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:13:56,716     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:13:56,744     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_full_fact_final/Chest_Deflection_HIII95_10_largest_channels
#   6%|▋         | 3/48 [00:05<01:19,  1.76s/it]2024-10-27 08:13:58,783     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:13:58,805     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:13:58,807     INFO  MainProcess  MainThread kern dropped
# 2024-10-27 08:13:58,808     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:13:58,808     INFO  MainProcess  MainThread FFTM dropped
# 2024-10-27 08:13:58,819     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:13:58,827     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:13:58,841     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 08:13:58,843     INFO  MainProcess  MainThread Added gid0 to subset
# 2024-10-27 08:13:58,845     INFO  MainProcess  MainThread Added first four glyphs to subset
# 2024-10-27 08:13:58,847     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 8 glyphs before
# 2024-10-27 08:13:58,849     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:13:58,852     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:13:58,855     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 8 glyphs after
# 2024-10-27 08:13:58,856     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:13:58,858     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:13:58,859     INFO  MainProcess  MainThread Closing glyph list over 'MATH': 8 glyphs before
# 2024-10-27 08:13:58,860     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:13:58,862     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:13:58,865     INFO  MainProcess  MainThread Closed glyph list over 'MATH': 8 glyphs after
# 2024-10-27 08:13:58,865     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:13:58,867     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:13:58,868     INFO  MainProcess  MainThread Closing glyph list over 'glyf': 8 glyphs before
# 2024-10-27 08:13:58,869     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:13:58,870     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:13:58,872     INFO  MainProcess  MainThread Closed glyph list over 'glyf': 8 glyphs after
# 2024-10-27 08:13:58,873     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:13:58,874     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:13:58,876     INFO  MainProcess  MainThread Retaining 8 glyphs
# 2024-10-27 08:13:58,881     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:13:58,882     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:13:58,883     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:13:58,884     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:13:58,896     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:13:58,904     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:13:58,905     INFO  MainProcess  MainThread fpgm subsetting not needed
# 2024-10-27 08:13:58,906     INFO  MainProcess  MainThread prep subsetting not needed
# 2024-10-27 08:13:58,912     INFO  MainProcess  MainThread cvt  subsetting not needed
# 2024-10-27 08:13:58,913     INFO  MainProcess  MainThread loca subsetting not needed
# 2024-10-27 08:13:58,915     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:13:58,916     INFO  MainProcess  MainThread gasp subsetting not needed
# 2024-10-27 08:13:58,917     INFO  MainProcess  MainThread MATH subsetted
# 2024-10-27 08:13:58,926     INFO  MainProcess  MainThread GDEF subsetted
# 2024-10-27 08:13:58,980     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:13:58,983     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:13:58,984     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:13:58,987     INFO  MainProcess  MainThread glyf subsetted
# 2024-10-27 08:13:58,988     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:13:58,989     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:13:58,990     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:13:58,991     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 08:13:58,992     INFO  MainProcess  MainThread GDEF pruned
# 2024-10-27 08:13:58,993     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:13:58,994     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:13:58,999     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:13:59,011     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:13:59,017     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:13:59,018     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:13:59,020     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:13:59,024     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:13:59,035     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:13:59,037     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:13:59,038     INFO  MainProcess  MainThread Closing glyph list over 'GSUB':
INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:00,995     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:01,011     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 08:14:01,014     INFO  MainProcess  MainThread Added gid0 to subset
# 2024-10-27 08:14:01,016     INFO  MainProcess  MainThread Added first four glyphs to subset
# 2024-10-27 08:14:01,017     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 8 glyphs before
# 2024-10-27 08:14:01,018     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:14:01,028     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:14:01,031     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 8 glyphs after
# 2024-10-27 08:14:01,033     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:14:01,034     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:14:01,035     INFO  MainProcess  MainThread Closing glyph list over 'MATH': 8 glyphs before
# 2024-10-27 08:14:01,036     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:14:01,044     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:14:01,046     INFO  MainProcess  MainThread Closed glyph list over 'MATH': 8 glyphs after
# 2024-10-27 08:14:01,047     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:14:01,048     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:14:01,049     INFO  MainProcess  MainThread Closing glyph list over 'glyf': 8 glyphs before
# 2024-10-27 08:14:01,052     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:14:01,053     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:14:01,054     INFO  MainProcess  MainThread Closed glyph list over 'glyf': 8 glyphs after
# 2024-10-27 08:14:01,055     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:14:01,056     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:14:01,058     INFO  MainProcess  MainThread Retaining 8 glyphs
# 2024-10-27 08:14:01,059     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:14:01,060     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:14:01,068     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:14:01,069     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:14:01,091     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:14:01,102     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:14:01,103     INFO  MainProcess  MainThread fpgm subsetting not needed
# 2024-10-27 08:14:01,104     INFO  MainProcess  MainThread prep subsetting not needed
# 2024-10-27 08:14:01,105     INFO  MainProcess  MainThread cvt  subsetting not needed
# 2024-10-27 08:14:01,106     INFO  MainProcess  MainThread loca subsetting not needed
# 2024-10-27 08:14:01,107     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:14:01,108     INFO  MainProcess  MainThread gasp subsetting not needed
# 2024-10-27 08:14:01,109     INFO  MainProcess  MainThread MATH subsetted
# 2024-10-27 08:14:01,124     INFO  MainProcess  MainThread GDEF subsetted
# 2024-10-27 08:14:01,179     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:14:01,182     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:14:01,183     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:14:01,188     INFO  MainProcess  MainThread glyf subsetted
# 2024-10-27 08:14:01,189     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:14:01,190     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:14:01,191     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:14:01,192     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 08:14:01,193     INFO  MainProcess  MainThread GDEF pruned
# 2024-10-27 08:14:01,193     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:01,194     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:01,199     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:14:01,210     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:14:01,217     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:14:01,219     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:14:01,221     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:14:01,225     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:01,234     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:01,236     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:14:01,237     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 13 glyphs before
# 2024-10-27 08:14:01,238     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'H', 'I', 'M', 'e', 'five', 'h', 'hyphen', 's', 'space', 't', 'zero']
# 2024-10-27 08:14:01,239     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 51, 57, 63, 64, 65, 66, 75, 99, 104, 106, 122]
# 2024-10-27 08:14:01,241     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 13 glyphs after
# 2024-10-27 08:14:01,242     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'H', 'I', 'M', 'e', 'five', 'h', 'hyphen', 's', 'space', 't', 'zero']
# 2024-10-27 08:14:01,243     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 51, 57, 63, 64, 65, 66, 75, 99, 104, 106, 122]
# 2024-10-27 08:14:01,243     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 13 glyphs before
# 2024-10-27 08:14:01,244     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'H', 'I', 'M', 'e', 'five', 'h', 'hyphen', 's', 'space', 't', 'zero']
# 2024-10-27 08:14:01,245     INFO  MainProcess  MainThread Glyph IDs:   [0, 43,
INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 08:14:45,313     INFO  MainProcess  MainThread Added gid0 to subset
# 2024-10-27 08:14:45,314     INFO  MainProcess  MainThread Added first four glyphs to subset
# 2024-10-27 08:14:45,315     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 15 glyphs before
# 2024-10-27 08:14:45,316     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'E', 'M', 'comma', 'e', 'i', 'n', 'nonmarkingreturn', 'o', 's', 'space', 't', 'x', 'y']
# 2024-10-27 08:14:45,318     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 40, 48, 72, 76, 81, 82, 86, 87, 91, 92]
# 2024-10-27 08:14:45,326     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 15 glyphs after
# 2024-10-27 08:14:45,327     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'E', 'M', 'comma', 'e', 'i', 'n', 'nonmarkingreturn', 'o', 's', 'space', 't', 'x', 'y']
# 2024-10-27 08:14:45,329     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 40, 48, 72, 76, 81, 82, 86, 87, 91, 92]
# 2024-10-27 08:14:45,330     INFO  MainProcess  MainThread Closing glyph list over 'MATH': 15 glyphs before
# 2024-10-27 08:14:45,331     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'E', 'M', 'comma', 'e', 'i', 'n', 'nonmarkingreturn', 'o', 's', 'space', 't', 'x', 'y']
# 2024-10-27 08:14:45,333     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 40, 48, 72, 76, 81, 82, 86, 87, 91, 92]
# 2024-10-27 08:14:45,334     INFO  MainProcess  MainThread Closed glyph list over 'MATH': 15 glyphs after
# 2024-10-27 08:14:45,335     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'E', 'M', 'comma', 'e', 'i', 'n', 'nonmarkingreturn', 'o', 's', 'space', 't', 'x', 'y']
# 2024-10-27 08:14:45,337     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 40, 48, 72, 76, 81, 82, 86, 87, 91, 92]
# 2024-10-27 08:14:45,337     INFO  MainProcess  MainThread Closing glyph list over 'glyf': 15 glyphs before
# 2024-10-27 08:14:45,338     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'E', 'M', 'comma', 'e', 'i', 'n', 'nonmarkingreturn', 'o', 's', 'space', 't', 'x', 'y']
# 2024-10-27 08:14:45,340     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 40, 48, 72, 76, 81, 82, 86, 87, 91, 92]
# 2024-10-27 08:14:45,341     INFO  MainProcess  MainThread Closed glyph list over 'glyf': 15 glyphs after
# 2024-10-27 08:14:45,342     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'E', 'M', 'comma', 'e', 'i', 'n', 'nonmarkingreturn', 'o', 's', 'space', 't', 'x', 'y']
# 2024-10-27 08:14:45,343     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 40, 48, 72, 76, 81, 82, 86, 87, 91, 92]
# 2024-10-27 08:14:45,344     INFO  MainProcess  MainThread Retaining 15 glyphs
# 2024-10-27 08:14:45,346     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:14:45,347     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:14:45,348     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:14:45,349     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:14:45,359     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:14:45,364     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:14:45,366     INFO  MainProcess  MainThread fpgm subsetting not needed
# 2024-10-27 08:14:45,368     INFO  MainProcess  MainThread prep subsetting not needed
# 2024-10-27 08:14:45,369     INFO  MainProcess  MainThread cvt  subsetting not needed
# 2024-10-27 08:14:45,370     INFO  MainProcess  MainThread loca subsetting not needed
# 2024-10-27 08:14:45,377     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:14:45,378     INFO  MainProcess  MainThread gasp subsetting not needed
# 2024-10-27 08:14:45,380     INFO  MainProcess  MainThread MATH subsetted
# 2024-10-27 08:14:45,384     INFO  MainProcess  MainThread GDEF subsetted
# 2024-10-27 08:14:45,517     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:14:45,521     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:14:45,522     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:14:45,526     INFO  MainProcess  MainThread glyf subsetted
# 2024-10-27 08:14:45,528     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:14:45,535     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:14:45,537     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:14:45,539     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 08:14:45,540     INFO  MainProcess  MainThread GDEF pruned
# 2024-10-27 08:14:45,541     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:45,544     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:45,551     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:14:45,572     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:14:45,586     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:14:45,587     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:14:45,592     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:14:45,596     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:45,616     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:45,618     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:14:45,619     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 12 glyphs before
# 2024-10-27 08:14:45,623     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'H', 'I', 'M', 'N', 'c', 'e', 'five', 'hyphen', 'k', 'nine', 'space']
# 2024-10-27 08:14:45,627     INFO  MainProcess  MainThread Glyph IDs:   [0, 44, 51, 57, 63, 65, 66, 71, 75, 77, 79, 104]
# 2024-10-27 08:14:45,629     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 12 glyphs after
# 2024-10-27 08:14:45,631     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'H', 'I', 'M', 'N', 'c', 'e', 'five', 'hyphen', 'k', 'nine', 'space']
# 2024-10-27 08:14:45,633     INFO  MainProcess  MainThread Glyph IDs:   [0, 44, 51, 57, 63, 65, 66, 71, 75, 77, 79, 104]
# 2024-10-27 08:14:45,639     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 12 glyphs before
# 2024-10-27 08:14:45,641     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'H', 'I', 'M', 'N', 'c', 'e', 'five', 'hyphen', 'k', 'nine', 'space']
# 2024-10-27 08:14:45,642     INFO  MainProcess  MainThread Glyph IDs:   [0, 44, 51, 57, 63, 65, 66, 71, 75, 77, 79, 104]
# 2024-10-27 08:14:45,647     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 12 glyphs after
# 2024-10-27 08:14:45,648     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'H', 'I', 'M', 'N', 'c', 'e', 'five', 'hyphen', 'k', 'nine', 'space']
# 2024-10-27 08:14:45,649     INFO  MainProcess  MainThread Glyph IDs:   [0, 44, 51, 57, 63, 65, 66, 71, 75, 77, 79, 104]
# 2024-10-27 08:14:45,651     INFO  MainProcess  MainThread Retaining 12 glyphs
# 2024-10-27 08:14:45,653     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:14:45,654     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:14:45,656     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:14:45,660     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:14:45,661     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:14:45,662     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:14:45,664     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:14:45,669     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:14:45,677     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:14:45,678     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:14:45,681     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:14:45,685     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:14:45,687     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:14:45,689     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:14:45,693     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:14:45,695     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:45,700     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:45,703     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:14:45,722     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:14:45,728     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:14:45,729     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:14:45,732     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:14:45,744     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:45,778     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:45,780     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:14:45,781     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 24 glyphs before
# 2024-10-27 08:14:45,782     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'I', 'K', 'M', 'N', 'O', 'P', 'T', 'U', 'Y', 'eight', 'five', 'four', 'minus', 'nine', 'one', 'seven', 'six', 'three', 'two', 'zero']
# 2024-10-27 08:14:45,783     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 47, 50, 52, 57, 58, 66, 70, 75, 77, 79, 81, 83, 84, 101, 102, 105, 107, 108, 109, 118, 122, 419]
# 2024-10-27 08:14:45,784     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 24 glyphs after
# 2024-10-27 08:14:45,798     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'I', 'K', 'M', 'N', 'O', 'P', 'T', 'U', 'Y', 'eight', 'five', 'four', 'minus', 'nine', 'one', 'seven', 'six', 'three', 'two', 'zero']
# 2024-10-27 08:14:45,800     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 47, 50, 52, 57, 58, 66, 70, 75, 77, 79, 81, 83, 84, 101, 102, 105, 107, 108, 109, 118, 122, 419]
# 2024-10-27 08:14:45,801     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 24 glyphs before
# 2024-10-27 08:14:45,802     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'I', 'K', 'M', 'N', 'O', 'P', 'T', 'U', 'Y', 'eight', 'five', 'four', 'minus', 'nine', 'one', 'seven', 'six', 'three', 'two', 'zero']
# 2024-10-27 08:14:45,814     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 47, 50, 52, 57, 58, 66, 70, 75, 77, 79, 81, 83, 84, 101, 102, 105, 107, 108, 109, 118, 122, 419]
# 2024-10-27 08:14:45,820     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 24 glyphs after
# 2024-10-27 08:14:45,822     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'I', 'K', 'M', 'N', 'O', 'P', 'T', 'U', 'Y', 'eight', 'five', 'four', 'minus', 'nine', 'one', 'seven', 'six', 'three', 'two', 'zero']
# 2024-10-27 08:14:45,823     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 47, 50, 52, 57, 58, 66, 70, 75, 77, 79, 81, 83, 84, 101, 102, 105, 107, 108, 109, 118, 122, 419]
# 2024-10-27 08:14:45,824     INFO  MainProcess  MainThread Retaining 24 glyphs
# 2024-10-27 08:14:45,825     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:14:45,826     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:14:45,830     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:14:45,830     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:14:45,836     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:14:45,838     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:14:45,840     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:14:45,842     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:14:45,878     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:14:45,881     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:14:45,885     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:14:45,887     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:14:45,888     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:14:45,889     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:14:45,895     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:14:45,896     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:45,898     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:45,903     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:14:45,929     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_full_fact_final/Neck_My_Extension_HIII95_10_largest_channels
# 100%|██████████| 48/48 [00:54<00:00,  1.13s/it]

# %%
DROPPED_IDS: Dict[int, List[int]] = {
    5: [120, 195, 220, 245, 345, 370, 495],
    50: [],
    95: [123, 635, 2393],
}
json_util.dump(obj=DROPPED_IDS, f_path=DATA_DIR / STR.fname_dropped_ids)
DROPPED_IDS
# Out:
# {5: [120, 195, 220, 245, 345, 370, 495], 50: [], 95: [123, 635, 2393]}

# %%
def box_and_rug_cleaned():
    percs = [5, 50, 95]
    inj_names = INJURIES

    fig_width: float = WIDTH
    fig_height: float = 1.35*WIDTH

    fig, ax = plt.subplots(
        nrows=len(inj_names),
        ncols=len(percs),
        layout="constrained",
        figsize=(fig_width, fig_height),
    )

    # plot
    versions = list(product(list(enumerate(inj_names)), list(enumerate(percs))))
    for (row, inj_val), (col, perc) in tqdm(versions):
        single_box_and_rug(inj_val=inj_val, perc=perc, ax=ax[row, col], drop_ids=DROPPED_IDS)
        ax[row, 0].set_ylabel(INJ_NAMES[inj_val])
        ax[row, col].set_xlabel("")
        ax[0, col].set_title(f"HIII {perc:02d} {'F' if perc == 5 else 'M'}")

    save_fig(fig=fig, f_name="injury_criteria_box_and_rug_cleaned")


box_and_rug_cleaned()
# Out:
# 100%|██████████| 27/27 [00:04<00:00,  6.68it/s]
# 2024-10-27 08:15:03,534     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:15:03,549     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:15:03,551     INFO  MainProcess  MainThread kern dropped
# 2024-10-27 08:15:03,552     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:15:03,553     INFO  MainProcess  MainThread FFTM dropped
# 2024-10-27 08:15:03,558     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:03,564     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:03,576     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 08:15:03,578     INFO  MainProcess  MainThread Added gid0 to subset
# 2024-10-27 08:15:03,580     INFO  MainProcess  MainThread Added first four glyphs to subset
# 2024-10-27 08:15:03,580     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 30 glyphs before
# 2024-10-27 08:15:03,581     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 08:15:03,584     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 08:15:03,590     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 30 glyphs after
# 2024-10-27 08:15:03,591     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 08:15:03,593     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 08:15:03,595     INFO  MainProcess  MainThread Closing glyph list over 'MATH': 30 glyphs before
# 2024-10-27 08:15:03,597     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 08:15:03,598     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 08:15:03,601     INFO  MainProcess  MainThread Closed glyph list over 'MATH': 30 glyphs after
# 2024-10-27 08:15:03,601     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 08:15:03,603     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 08:15:03,603     INFO  MainProcess  MainThread Closing glyph list over 'glyf': 30 glyphs before
# 2024-10-27 08:15:03,604     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27
INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_full_fact_final/injury_criteria_box_and_rug_cleaned

# %%
def plot_dropped_grid():
    # get data
    doe = pd.read_parquet(DOE_FPATH)
    factors = sorted(doe.columns)
    parser = pd.read_parquet(SIMID2ID_FPATH).reset_index().set_index([STR.id, STR.perc])

    # plot
    fig, ax = plt.subplots(
        ncols=doe.shape[1],
        nrows=doe.shape[1] + 1,
        figsize=(WIDTH, WIDTH),
        sharex="col",
        sharey="row",
        layout="constrained",
        height_ratios=[0.1] + [1] * doe.shape[1],
    )
    gs = ax[0, 0].get_gridspec()
    for a in ax[0]:
        a.remove()
    axbig = fig.add_subplot(gs[0, :])
    axbig.axis("off")

    for i, x_axis in enumerate(factors):
        for j, y_axis in enumerate(factors):
            ax[i + 1, j].scatter(doe[y_axis], doe[x_axis], color="b", label="DoE", s=0.05)

            for q, perc in enumerate(DROPPED_IDS.keys()):
                locs = parser.loc[(DROPPED_IDS[perc], perc), :].values.flatten()
                ax[i + 1, j].scatter(
                    doe.loc[locs, y_axis],
                    doe.loc[locs, x_axis],
                    color="r",
                    label=f"Dropped HIII{perc:02d}{'F' if perc == 5 else 'M'}  n={len(DROPPED_IDS[perc])}",
                    marker=["+", "x", "*"][q],
                )
            ax[i + 1, j].grid()
            ax[i + 1, j].set_axisbelow(True)

    for i, label in enumerate(factors):
        ax[-1, i].set_xlabel(label)
        ax[i + 1, 0].set_ylabel(label)
    axbig.legend(*ax[-1, -1].get_legend_handles_labels(), ncols=4, loc="center")

    save_fig(fig=fig, f_name="doe_dropped_ids")


plot_dropped_grid()
# Out:
# 2024-10-27 08:15:18,327     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:15:18,333     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:15:18,334     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:15:18,336     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:15:18,339     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:18,347     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:18,349     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:15:18,350     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 44 glyphs before
# 2024-10-27 08:15:18,352     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'B', 'C', 'D', 'E', 'F', 'H', 'I', 'L', 'M', 'P', 'R', 'S', 'T', 'V', 'X', 'a', 'c', 'd', 'e', 'eight', 'equal', 'five', 'four', 'g', 'l', 'minus', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'space', 't', 'three', 'two', 'u', 'underscore', 'zero']
# 2024-10-27 08:15:18,353     INFO  MainProcess  MainThread Glyph IDs:   [0, 28, 29, 35, 43, 44, 47, 48, 50, 51, 52, 53, 55, 57, 58, 60, 63, 66, 72, 73, 75, 78, 79, 82, 83, 84, 85, 89, 96, 97, 98, 99, 101, 104, 105, 106, 107, 108, 110, 111, 112, 116, 122, 419]
# 2024-10-27 08:15:18,355     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 44 glyphs after
# 2024-10-27 08:15:18,356     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'B', 'C', 'D', 'E', 'F', 'H', 'I', 'L', 'M', 'P', 'R', 'S', 'T', 'V', 'X', 'a', 'c', 'd', 'e', 'eight', 'equal', 'five', 'four', 'g', 'l', 'minus', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'space', 't', 'three', 'two', 'u', 'underscore', 'zero']
# 2024-10-27 08:15:18,357     INFO  MainProcess  MainThread Glyph IDs:   [0, 28, 29, 35, 43, 44, 47, 48, 50, 51, 52, 53, 55, 57, 58, 60, 63, 66, 72, 73, 75, 78, 79, 82, 83, 84, 85, 89, 96, 97, 98, 99, 101, 104, 105, 106, 107, 108, 110, 111, 112, 116, 122, 419]
# 2024-10-27 08:15:18,358     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 44 glyphs before
# 2024-10-27 08:15:18,358     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'B', 'C', 'D', 'E', 'F', 'H', 'I', 'L', 'M', 'P', 'R', 'S', 'T', 'V', 'X', 'a', 'c', 'd', 'e', 'eight', 'equal', 'five', 'four', 'g', 'l', 'minus', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'space', 't', 'three', 'two', 'u', 'underscore', 'zero']
# 2024-10-27 08:15:18,359     INFO  MainProcess  MainThread Glyph IDs:   [0, 28, 29, 35, 43, 44, 47, 48, 50, 51, 52, 53, 55, 57, 58, 60, 63, 66, 72, 73, 75, 78, 79, 82, 83, 84, 85, 89, 96, 97, 98, 99, 101, 104, 105, 106, 107, 108, 110, 111, 112, 116, 122, 419]
# 2024-10-27 08:15:18,365     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 44 glyphs after
# 2024-10-27 08:15:18,366     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'B', 'C', 'D', 'E', 'F', 'H', 'I', 'L', 'M', 'P', 'R', 'S', 'T', 'V', 'X', 'a', 'c', 'd', 'e', 'eight', 'equal', 'five', 'four', 'g', 'l', 'minus', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'space', 't', 'three', 'two', 'u', 'underscore', 'zero']
# 2024-10-27 08:15:18,367     INFO  MainProcess  MainThread Glyph IDs:   [0, 28, 29, 35, 43, 44, 47, 48, 50, 51, 52, 53, 55, 57, 58, 60, 63, 66, 72, 73, 75, 78, 79, 82, 83, 84, 85, 89, 96, 97, 98, 99, 101, 104, 105, 106, 107, 108, 110, 111, 112, 116, 122, 419]
# 2024-10-27 08:15:18,368     INFO  MainProcess  MainThread Retaining 44 glyphs
# 2024-10-27 08:15:18,369     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:15:18,369     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:15:18,370     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:15:18,371     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:15:18,372     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:15:18,373     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:15:18,374     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:15:18,376     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:15:18,406     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:15:18,407     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:15:18,408     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:15:18,409     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:15:18,410     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:15:18,411     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:15:18,415     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:15:18,417     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:18,417     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:18,422     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:15:18,453     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_full_fact_final/doe_dropped_ids

# %%
def plot_bars(point_db: pd.DataFrame, fig_title: str, store: bool = True, sort_by_all: bool = True) -> None:
    if sort_by_all:
        existing_points = [str(x) for x in sorted(set(point_db.to_numpy().flatten()))]
    percs = sorted(point_db.index.get_level_values(STR.perc).unique())

    for perc in percs:
        for idx in DROPPED_IDS[perc]:
            try:
                point_db.drop(index=[idx, perc], inplace=True)
            except KeyError:
                LOG.warning("Could not drop index %s of perc %s", idx, perc)

    fig_width: float = WIDTH
    fig_height: float = 0.7 * fig_width
    fig, ax = plt.subplots(
        ncols=point_db.shape[1],
        nrows=len(percs),
        figsize=(fig_width, fig_height),
        sharex=True,
        sharey=True if sort_by_all else "row",
        layout="constrained",
    )
    fig.suptitle(fig_title)
    vers = list(product(list(enumerate(point_db.columns)), list(enumerate(percs))))
    for (col, val), (row, perc) in vers:
        if not sort_by_all:
            existing_points = [
                str(x)
                for x in sorted(
                    set(point_db.loc[(slice(None), perc), val].to_numpy().flatten()), key=lambda x: int(x.split(":")[0])
                )
            ]
        cnt = [str(x) for x in point_db.loc[(slice(None), perc), val].to_list()]
        sns.countplot(
            cnt,
            ax=ax[row, col],
            order=existing_points,
            alpha=0.5,
            native_scale=False,
        )
        ax[0, col].set_title(val, size="x-small")
        ax[row, 0].set_ylabel(f"HIII{perc:02} - n={len(cnt)}")
        ax[row, col].set_xlim([0, 9000])
        ax[row, col].bar_label(ax[row, col].containers[0], fontsize=7, rotation=90, padding=2)
    if store:
        save_fig(fig=fig, f_name=f"{'_'.join(fig_title.lower().split())}_distribution_bars")


plot_bars(
    point_db=pd.concat(
        [LoadForClassification(data_directory=DATA_DIR).injury_value_to_points(percentile=perc) for perc in (5, 95)], axis=0
    ),
    fig_title="Points by Euro NCAP",
    store=True,
)
# Out:
# 2024-10-27 08:15:18,477     INFO  MainProcess  MainThread Directory '/root/py_projects/aihiii/data/doe/doe_big_grid_20230922_154140' exists
# 2024-10-27 08:15:18,479     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_big_grid_20230922_154140/injury_criteria.parquet' exists
# 2024-10-27 08:15:18,481     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_big_grid_20230922_154140/results_info.json' exists
# 2024-10-27 08:15:18,542     INFO  MainProcess  MainThread Hashes of injury files are the same
# 2024-10-27 08:15:18,802     INFO  MainProcess  MainThread Directory '/root/py_projects/aihiii/data/doe/doe_big_grid_20230922_154140' exists
# 2024-10-27 08:15:18,803     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_big_grid_20230922_154140/injury_criteria.parquet' exists
# 2024-10-27 08:15:18,804     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_big_grid_20230922_154140/results_info.json' exists
# 2024-10-27 08:15:18,856     INFO  MainProcess  MainThread Hashes of injury files are the same
# /tmp/ipykernel_3462606/3553979003.py:9: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   point_db.drop(index=[idx, perc], inplace=True)
# 2024-10-27 08:15:19,352  WARNING  MainProcess  MainThread Could not drop index 195 of perc 5.0
# 2024-10-27 08:15:19,353  WARNING  MainProcess  MainThread Could not drop index 220 of perc 5.0
# 2024-10-27 08:15:19,363  WARNING  MainProcess  MainThread Could not drop index 245 of perc 5.0
# 2024-10-27 08:15:19,364  WARNING  MainProcess  MainThread Could not drop index 345 of perc 5.0
# 2024-10-27 08:15:19,367  WARNING  MainProcess  MainThread Could not drop index 370 of perc 5.0
# 2024-10-27 08:15:19,368  WARNING  MainProcess  MainThread Could not drop index 495 of perc 5.0
# 2024-10-27 08:15:19,372  WARNING  MainProcess  MainThread Could not drop index 635 of perc 95.0
# 2024-10-27 08:15:19,374  WARNING  MainProcess  MainThread Could not drop index 2393 of perc 95.0
# 2024-10-27 08:15:19,736     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:19,753     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:19,867     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:19,880     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:19,980     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:19,990     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:20,336     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:20,346     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:20,421     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:20,430     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:20,508     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:20,520     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:20,622     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:20,635     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:20,712     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:20,725     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:20,811     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:20,819     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:20,902     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:20,914     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:20,994     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:21,002     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:21,070     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:21,079     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:21,161     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:21,169     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:21,229     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:21,237     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:21,303     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:21,313     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:21,385     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:21,397     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:15:23,815     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:15:23,820     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:15:23,822     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:15:23,823     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:15:23,828     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:23,841     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:23,843     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:15:23,844     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 16 glyphs before
# 2024-10-27 08:15:23,845     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'C', 'E', 'N', 'P', 'b', 'i', 'n', 'o', 'r', 's', 'space', 't', 'u', 'y']
# 2024-10-27 08:15:23,846     INFO  MainProcess  MainThread Glyph IDs:   [0, 28, 36, 43, 50, 67, 77, 78, 82, 84, 97, 99, 104, 106, 110, 119]
# 2024-10-27 08:15:23,848     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 16 glyphs after
# 2024-10-27 08:15:23,849     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'C', 'E', 'N', 'P', 'b', 'i', 'n', 'o', 'r', 's', 'space', 't', 'u', 'y']
# 2024-10-27 08:15:23,850     INFO  MainProcess  MainThread Glyph IDs:   [0, 28, 36, 43, 50, 67, 77, 78, 82, 84, 97, 99, 104, 106, 110, 119]
# 2024-10-27 08:15:23,851     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 16 glyphs before
# 2024-10-27 08:15:23,852     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'C', 'E', 'N', 'P', 'b', 'i', 'n', 'o', 'r', 's', 'space', 't', 'u', 'y']
# 2024-10-27 08:15:23,853     INFO  MainProcess  MainThread Glyph IDs:   [0, 28, 36, 43, 50, 67, 77, 78, 82, 84, 97, 99, 104, 106, 110, 119]
# 2024-10-27 08:15:23,857     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 16 glyphs after
# 2024-10-27 08:15:23,858     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'C', 'E', 'N', 'P', 'b', 'i', 'n', 'o', 'r', 's', 'space', 't', 'u', 'y']
# 2024-10-27 08:15:23,859     INFO  MainProcess  MainThread Glyph IDs:   [0, 28, 36, 43, 50, 67, 77, 78, 82, 84, 97, 99, 104, 106, 110, 119]
# 2024-10-27 08:15:23,863     INFO  MainProcess  MainThread Retaining 16 glyphs
# 2024-10-27 08:15:23,864     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:15:23,865     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:15:23,866     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:15:23,867     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:15:23,869     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:15:23,870     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:15:23,871     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:15:23,876     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:15:23,893     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:15:23,894     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:15:23,895     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:15:23,896     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:15:23,896     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:15:23,897     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:15:23,899     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:15:23,900     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:23,901     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:23,904     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:15:23,917     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:15:23,923     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:15:23,925     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:15:23,929     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:15:23,933     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:23,942     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:23,944     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:15:23,944     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 47 glyphs before
# 2024-10-27 08:15:23,945     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'S', 'T', 'V', 'a', 'c', 'd', 'e', 'eight', 'equal', 'f', 'five', 'four', 'h', 'hyphen', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:15:23,947     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 63, 64, 65, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122]
# 2024-10-27 08:15:23,949     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 53 glyphs after
# 2024-10-27 08:15:23,953     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'S', 'T', 'V', 'a', 'c', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'h', 'hyphen', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:15:23,954     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 63, 64, 65, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:15:23,955     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 53 glyphs before
# 2024-10-27 08:15:23,956     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'S', 'T', 'V', 'a', 'c', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'h', 'hyphen', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:15:23,957     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 63, 64, 65, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:15:23,967     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 53 glyphs after
# 2024-10-27 08:15:23,968     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'S', 'T', 'V', 'a', 'c', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'h', 'hyphen', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:15:23,969     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 63, 64, 65, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:15:23,970     INFO  MainProcess  MainThread Retaining 53 glyphs
# 2024-10-27 08:15:23,971     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:15:23,972     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:15:23,973     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:15:23,974     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:15:23,976     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:15:23,977     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:15:23,979     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:15:23,981     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:15:24,019     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:15:24,021     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:15:24,022     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:15:24,024     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:15:24,033     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:15:24,035     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:15:24,053     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:15:24,055     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:24,057     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:24,073     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:15:24,113     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_full_fact_final/points_by_euro_ncap_distribution_bars

# %%
def plot_classes(n_classes: int):
    LOG.info("Plotting classes with %s classes", n_classes)
    db = pd.read_parquet(CLASSES_FPATHS[n_classes])
    db = pd.concat([db.loc[(slice(None), perc), :].replace(RENAMER[perc][n_classes]) for perc in (5, 95)], axis=0)

    plot_bars(point_db=db, fig_title=f"Classification with {n_classes} Classes", store=True, sort_by_all=False)


_ = [plot_classes(n_classes=n_classes) for n_classes in CLASSES_FPATHS.keys()]
# Out:
# 2024-10-27 08:15:24,136     INFO  MainProcess  MainThread Plotting classes with 2 classes
# /tmp/ipykernel_3462606/3553979003.py:9: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   point_db.drop(index=[idx, perc], inplace=True)
# 2024-10-27 08:15:24,178  WARNING  MainProcess  MainThread Could not drop index 195 of perc 5.0
# 2024-10-27 08:15:24,180  WARNING  MainProcess  MainThread Could not drop index 220 of perc 5.0
# 2024-10-27 08:15:24,181  WARNING  MainProcess  MainThread Could not drop index 245 of perc 5.0
# 2024-10-27 08:15:24,183  WARNING  MainProcess  MainThread Could not drop index 345 of perc 5.0
# 2024-10-27 08:15:24,185  WARNING  MainProcess  MainThread Could not drop index 370 of perc 5.0
# 2024-10-27 08:15:24,188  WARNING  MainProcess  MainThread Could not drop index 495 of perc 5.0
# 2024-10-27 08:15:24,195  WARNING  MainProcess  MainThread Could not drop index 635 of perc 95.0
# 2024-10-27 08:15:24,197  WARNING  MainProcess  MainThread Could not drop index 2393 of perc 95.0
# 2024-10-27 08:15:26,721     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:15:26,728     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:15:26,729     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:15:26,732     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:15:26,736     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:26,744     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:26,745     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:15:26,746     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 16 glyphs before
# 2024-10-27 08:15:26,747     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'h', 'i', 'l', 'n', 'o', 's', 'space', 't', 'two', 'w']
# 2024-10-27 08:15:26,748     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 104, 106, 108, 115]
# 2024-10-27 08:15:26,749     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 21 glyphs after
# 2024-10-27 08:15:26,751     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'space', 't', 'two', 'w']
# 2024-10-27 08:15:26,752     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 104, 106, 108, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:15:26,752     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 21 glyphs before
# 2024-10-27 08:15:26,753     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'space', 't', 'two', 'w']
# 2024-10-27 08:15:26,754     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 104, 106, 108, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:15:26,758     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 21 glyphs after
# 2024-10-27 08:15:26,759     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'space', 't', 'two', 'w']
# 2024-10-27 08:15:26,760     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 104, 106, 108, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:15:26,762     INFO  MainProcess  MainThread Retaining 21 glyphs
# 2024-10-27 08:15:26,763     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:15:26,764     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:15:26,765     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:15:26,766     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:15:26,767     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:15:26,768     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:15:26,769     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:15:26,771     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:15:26,776     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:15:26,778     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:15:26,778     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:15:26,780     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:15:26,781     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:15:26,782     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:15:26,785     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:15:26,787     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:26,788     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:26,793     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:15:26,808     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:15:26,813     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:15:26,815     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:15:26,817     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:15:26,820     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:26,831     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:26,832     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:15:26,833     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 51 glyphs before
# 2024-10-27 08:15:26,834     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:15:26,835     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122]
# 2024-10-27 08:15:26,837     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 57 glyphs after
# 2024-10-27 08:15:26,840     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:15:26,841     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:15:26,842     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 57 glyphs before
# 2024-10-27 08:15:26,843     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:15:26,844     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:15:26,856     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 57 glyphs after
# 2024-10-27 08:15:26,857     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:15:26,859     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:15:26,860     INFO  MainProcess  MainThread Retaining 57 glyphs
# 2024-10-27 08:15:26,861     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:15:26,862     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:15:26,863     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:15:26,864     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:15:26,865     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:15:26,867     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:15:26,868     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:15:26,870     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:15:27,068     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:15:27,070     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:15:27,070     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:15:27,072     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:15:27,072     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:15:27,073     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:15:27,079     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:15:27,081     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:27,082     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:27,094     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:15:27,113     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_full_fact_final/classification_with_2_classes_distribution_bars
# 2024-10-27 08:15:27,114     INFO  MainProcess  MainThread Plotting classes with 3 classes
# /tmp/ipykernel_3462606/3553979003.py:9: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   point_db.drop(index=[idx, perc], inplace=True)
# 2024-10-27 08:15:27,142  WARNING  MainProcess  MainThread Could not drop index 195 of perc 5.0
# 2024-10-27 08:15:27,143  WARNING  MainProcess  MainThread Could not drop index 220 of perc 5.0
# 2024-10-27 08:15:27,145  WARNING  MainProcess  MainThread Could not drop index 245 of perc 5.0
# 2024-10-27 08:15:27,145  WARNING  MainProcess  MainThread Could not drop index 345 of perc 5.0
# 2024-10-27 08:15:27,147  WARNING  MainProcess  MainThread Could not drop index 370 of perc 5.0
# 2024-10-27 08:15:27,148  WARNING  MainProcess  MainThread Could not drop index 495 of perc 5.0
# 2024-10-27 08:15:27,152  WARNING  MainProcess  MainThread Could not drop index 635 of perc 95.0
# 2024-10-27 08:15:27,154  WARNING  MainProcess  MainThread Could not drop index 2393 of perc 95.0
# 2024-10-27 08:15:29,431     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:15:29,436     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:15:29,437     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:15:29,439     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:15:29,442     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:29,451     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:29,452     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:15:29,453     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 16 glyphs before
# 2024-10-27 08:15:29,454     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'h', 'i', 'l', 'n', 'o', 's', 'space', 't', 'three', 'w']
# 2024-10-27 08:15:29,455     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 104, 106, 107, 115]
# 2024-10-27 08:15:29,457     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 21 glyphs after
# 2024-10-27 08:15:29,458     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'space', 't', 'three', 'w']
# 2024-10-27 08:15:29,459     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 104, 106, 107, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:15:29,460     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 21 glyphs before
# 2024-10-27 08:15:29,461     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'space', 't', 'three', 'w']
# 2024-10-27 08:15:29,462     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 104, 106, 107, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:15:29,466     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 21 glyphs after
# 2024-10-27 08:15:29,467     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'space', 't', 'three', 'w']
# 2024-10-27 08:15:29,473     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 104, 106, 107, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:15:29,475     INFO  MainProcess  MainThread Retaining 21 glyphs
# 2024-10-27 08:15:29,476     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:15:29,477     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:15:29,478     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:15:29,479     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:15:29,481     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:15:29,482     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:15:29,483     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:15:29,488     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:15:29,496     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:15:29,498     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:15:29,499     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:15:29,501     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:15:29,503     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:15:29,504     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:15:29,508     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:15:29,510     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:29,512     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:29,517     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:15:29,533     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:15:29,539     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:15:29,540     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:15:29,542     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:15:29,545     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:29,562     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:29,564     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:15:29,565     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 51 glyphs before
# 2024-10-27 08:15:29,566     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:15:29,567     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122]
# 2024-10-27 08:15:29,569     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 57 glyphs after
# 2024-10-27 08:15:29,570     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:15:29,571     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:15:29,571     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 57 glyphs before
# 2024-10-27 08:15:29,572     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:15:29,577     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:15:29,596     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 57 glyphs after
# 2024-10-27 08:15:29,597     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:15:29,599     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:15:29,600     INFO  MainProcess  MainThread Retaining 57 glyphs
# 2024-10-27 08:15:29,602     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:15:29,603     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:15:29,605     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:15:29,606     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:15:29,608     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:15:29,609     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:15:29,611     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:15:29,614     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:15:29,646     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:15:29,648     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:15:29,649     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:15:29,650     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:15:29,651     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:15:29,652     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:15:29,659     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:15:29,660     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:29,664     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:29,674     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:15:29,705     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_full_fact_final/classification_with_3_classes_distribution_bars
# 2024-10-27 08:15:29,707     INFO  MainProcess  MainThread Plotting classes with 5 classes
# /tmp/ipykernel_3462606/3553979003.py:9: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#
PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   point_db.drop(index=[idx, perc], inplace=True)
# 2024-10-27 08:15:33,378  WARNING  MainProcess  MainThread Could not drop index 195 of perc 5.0
# 2024-10-27 08:15:33,380  WARNING  MainProcess  MainThread Could not drop index 220 of perc 5.0
# 2024-10-27 08:15:33,381  WARNING  MainProcess  MainThread Could not drop index 245 of perc 5.0
# 2024-10-27 08:15:33,383  WARNING  MainProcess  MainThread Could not drop index 345 of perc 5.0
# 2024-10-27 08:15:33,384  WARNING  MainProcess  MainThread Could not drop index 370 of perc 5.0
# 2024-10-27 08:15:33,386  WARNING  MainProcess  MainThread Could not drop index 495 of perc 5.0
# 2024-10-27 08:15:33,392  WARNING  MainProcess  MainThread Could not drop index 635 of perc 95.0
# 2024-10-27 08:15:33,395  WARNING  MainProcess  MainThread Could not drop index 2393 of perc 95.0
# 2024-10-27 08:15:37,095     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:15:37,102     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:15:37,103     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:15:37,106     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:15:37,109     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:37,123     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:37,125     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:15:37,126     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 16 glyphs before
# 2024-10-27 08:15:37,127     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'h', 'i', 'l', 'n', 'o', 's', 'seven', 'space', 't', 'w']
# 2024-10-27 08:15:37,128     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 101, 104, 106, 115]
# 2024-10-27 08:15:37,129     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 21 glyphs after
# 2024-10-27 08:15:37,131     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'seven', 'space', 't', 'w']
# 2024-10-27 08:15:37,132     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 101, 104, 106, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:15:37,133     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 21 glyphs before
# 2024-10-27 08:15:37,133     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'seven', 'space', 't', 'w']
# 2024-10-27 08:15:37,134     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 101, 104, 106, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:15:37,138     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 21 glyphs after
# 2024-10-27 08:15:37,139     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'seven', 'space', 't', 'w']
# 2024-10-27 08:15:37,140     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 101, 104, 106, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:15:37,142     INFO  MainProcess  MainThread Retaining 21 glyphs
# 2024-10-27 08:15:37,143     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:15:37,144     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:15:37,145     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:15:37,147     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:15:37,148     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:15:37,150     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:15:37,154     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:15:37,156     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:15:37,165     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:15:37,166     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:15:37,167     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:15:37,168     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:15:37,169     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:15:37,170     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:15:37,175     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:15:37,177     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:37,179     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:37,183     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:15:37,203     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:15:37,210     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:15:37,211     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:15:37,216     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:15:37,219     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:37,230     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:37,232     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:15:37,233     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 51 glyphs before
# 2024-10-27 08:15:37,234     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:15:37,236     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122]
# 2024-10-27 08:15:37,238     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 57 glyphs after
# 2024-10-27 08:15:37,239     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:15:37,240     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:15:37,241     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 57 glyphs before
# 2024-10-27 08:15:37,242     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:15:37,243     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:15:37,251     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 57 glyphs after
# 2024-10-27 08:15:37,252     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:15:37,253     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:15:37,258     INFO  MainProcess  MainThread Retaining 57 glyphs
# 2024-10-27 08:15:37,261     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:15:37,262     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:15:37,263     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:15:37,264     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:15:37,267     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:15:37,269     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:15:37,271     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:15:37,273     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:15:37,301     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:15:37,302     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:15:37,303     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:15:37,305     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:15:37,306     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:15:37,307     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:15:37,318     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:15:37,320     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:37,324     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:37,333     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:15:37,369     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_full_fact_final/classification_with_7_classes_distribution_bars
