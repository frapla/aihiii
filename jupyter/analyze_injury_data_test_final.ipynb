# %%
import logging
import os
import sys
from itertools import product
from pathlib import Path
from typing import Dict, List, Optional

import IPython
import matplotlib
from seaborn._statistics import LetterValues
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pyarrow.parquet as pq
import seaborn as sns
import textalloc as ta
from tqdm import tqdm

NOTEBOOK_PATH: Path = Path(IPython.extract_module_locals()[1]["__vsc_ipynb_file__"])
PROJECT_DIR: Path = NOTEBOOK_PATH.parent.parent
sys.path.append(str(PROJECT_DIR))
import src.utils.custom_log as custom_log
from src._StandardNames import StandardNames
from src.load.LoadForClassification import RENAMER, LoadForClassification
from src.utils.PathChecker import PathChecker
from src.utils.set_rcparams import set_rcparams
import src.utils.json_util as json_util

os.chdir(PROJECT_DIR)
set_rcparams()

LOG: logging.Logger = logging.getLogger(__name__)
custom_log.init_logger(log_lvl=logging.INFO)
LOG.info("Log start, project directory is %s (exist: %s)", PROJECT_DIR, PROJECT_DIR.is_dir())

CHECK: PathChecker = PathChecker()
STR: StandardNames = StandardNames()

FIG_DIR: Path = CHECK.check_directory(PROJECT_DIR / "reports" / "figures", exit=False)
FIG_DIR /= NOTEBOOK_PATH.stem
FIG_DIR.mkdir(parents=True, exist_ok=True)
LOG.info("Figure directory is %s (exist: %s)", FIG_DIR, FIG_DIR.is_dir())

DATA_DIR: Path = CHECK.check_directory(PROJECT_DIR / "data" / "doe" / "doe_sobol_test_20240829_135200", exit=False)
INJ_FPATH: Path = CHECK.check_file(DATA_DIR / "injury_criteria.parquet", exit=False)
CLASSES_FPATHS: Dict[int, Path] = {
    i: CHECK.check_file(DATA_DIR / f"injury_criteria_classes_{i}.parquet", exit=False) for i in (2, 3, 5, 7)
}
CHANNELS_FPATH: Path = CHECK.check_file(DATA_DIR / "channels.parquet", exit=False)
DOE_FPATH: Path = CHECK.check_file(DATA_DIR / "doe.parquet", exit=False)
SIMID2ID_FPATH: Path = CHECK.check_file(DATA_DIR / "sim_id_2_id.parquet", exit=False)
# Out:
# 2024-10-27 06:46:23,422     INFO  MainProcess  MainThread Log start, project directory is /root/py_projects/aihiii (exist: True)
# 2024-10-27 06:46:23,423     INFO  MainProcess  MainThread Directory '/root/py_projects/aihiii/reports/figures' exists
# 2024-10-27 06:46:23,424     INFO  MainProcess  MainThread Figure directory is /root/py_projects/aihiii/reports/figures/analyze_injury_data_test_final (exist: True)
# 2024-10-27 06:46:23,425     INFO  MainProcess  MainThread Directory '/root/py_projects/aihiii/data/doe/doe_sobol_test_20240829_135200' exists
# 2024-10-27 06:46:23,426     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_sobol_test_20240829_135200/injury_criteria.parquet' exists
# 2024-10-27 06:46:23,427     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_sobol_test_20240829_135200/injury_criteria_classes_2.parquet' exists
# 2024-10-27 06:46:23,428     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_sobol_test_20240829_135200/injury_criteria_classes_3.parquet' exists
# 2024-10-27 06:46:23,430     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_sobol_test_20240829_135200/injury_criteria_classes_5.parquet' exists
# 2024-10-27 06:46:23,431     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_sobol_test_20240829_135200/injury_criteria_classes_7.parquet' exists
# 2024-10-27 06:46:23,432     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_sobol_test_20240829_135200/channels.parquet' exists
# 2024-10-27 06:46:23,432     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_sobol_test_20240829_135200/doe.parquet' exists
# 2024-10-27 06:46:23,434     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_sobol_test_20240829_135200/sim_id_2_id.parquet' exists

# %%
INJURIES: List[str] = [
    "Head_HIC15",
    "Head_a3ms",
    "Neck_My_Extension",
    "Neck_Fz_Max_Tension",
    "Neck_Fx_Shear_Max",
    "Chest_a3ms",
    "Chest_Deflection",
    "Chest_VC",
    "Femur_Fz_Max_Compression",
]
INJ_NAMES: Dict[str, str] = {
    "Head_HIC15": "Head $\\text{HIC}_\\text{15}$",
    "Head_a3ms": "Head $\\text{a}_\\text{3ms}$",
    "Neck_My_Extension": "Neck $\\text{M}_{\\text{y, Extension}}$",
    "Neck_Fz_Max_Tension": "Neck $\\text{F}_{\\text{z, Tension}}$",
    "Neck_Fx_Shear_Max": "Neck $\\text{F}_{\\text{x, Shear}}$",
    "Chest_a3ms": "Chest $\\text{a}_\\text{3ms}$",
    "Chest_Deflection": "Chest Deflection",
    "Chest_VC": "Chest VC",
    "Femur_Fz_Max_Compression": "Femur $\\text{F}_{\\text{z, Compression}}$",
}
WIDTH = 448.13095 / 72

# %%
def save_fig(fig: matplotlib.figure.Figure, f_name: str) -> None:
    f_path = FIG_DIR / f_name
    fig.savefig(f_path.with_suffix(".pdf"), transparent=False)
    LOG.info("Saved figure to %s", f_path)
    plt.close(fig)

# %%
def single_box_and_rug(inj_val: str, perc: int, ax, drop_ids: Optional[Dict[int, List[int]]] = None):
    filters = [(STR.perc, "==", perc)]
    if drop_ids is not None:
        filters += [(STR.id, "not in", drop_ids[perc])]

    db: pd.DataFrame = pd.read_parquet(INJ_FPATH, columns=[inj_val], filters=tuple(filters))[inj_val].droplevel(STR.perc)


    # base plot
    sns.rugplot(x=db, ax=ax, height=0.05)
    sns.boxenplot(
        x=db,
        ax=ax,
        fill=False,
        color=".5",
        linecolor="#137",
        flier_kws={"s": 0.2},
    )

    # extreme outlier
    if drop_ids is None:
        q1, q3 = db.quantile([0.25, 0.75])
        iqr = q3 - q1
        db_extreme = db[db.le(q1 - 3 * iqr) | db.ge(q3 + 3 * iqr)]
        if len(db_extreme) > 0:
            ax.scatter(
                db_extreme,
                [0] * len(db_extreme),
                color="r",
                marker="x",
                s=0.7,
                alpha=0.5,
            )
        
        fliers = LetterValues(k_depth="tukey", outlier_prop=0.007, trust_alpha=0.05)(db.values)["fliers"]
        idx = pd.Index(db.values)
        
        try:
            idx = [int(db.index[idx.get_loc(x)]) for x in fliers]

            ta.allocate(
                    ax=ax,
                    y=[0] * len(fliers),
                    x=fliers,
                    text_list=idx,
                    y_scatter=[0] * len(fliers),
                    x_scatter=fliers,
                    min_distance=0.1,
                    linecolor="g",
                    linewidth=0.2,
                    textsize=5,
                    avoid_label_lines_overlap=True,
                )
        except:
            pass

# %%
def box_and_rug():
    percs = [5, 50, 95]
    inj_names = INJURIES

    fig_width: float = WIDTH
    fig_height: float = 1.35*WIDTH

    fig, ax = plt.subplots(
        nrows=len(inj_names),
        ncols=len(percs),
        layout="constrained",
        figsize=(fig_width, fig_height),
    )

    # plot
    versions = list(product(list(enumerate(inj_names)), list(enumerate(percs))))
    for (row, inj_val), (col, perc) in tqdm(versions):
        single_box_and_rug(inj_val=inj_val, perc=perc, ax=ax[row, col])
        ax[row, 0].set_ylabel(INJ_NAMES[inj_val])
        ax[row, col].set_xlabel("")
        ax[0, col].set_title(f"HIII {perc:02d} {'F' if perc == 5 else 'M'}")

    save_fig(fig=fig, f_name="injury_criteria_box_and_rug")


box_and_rug()
# Out:
# 100%|██████████| 27/27 [00:29<00:00,  1.08s/it]
# 2024-10-27 06:46:55,735     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 06:46:55,750     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 06:46:55,754     INFO  MainProcess  MainThread kern dropped
# 2024-10-27 06:46:55,755     INFO  MainProcess  MainThread post pruned
# 2024-10-27 06:46:55,757     INFO  MainProcess  MainThread FFTM dropped
# 2024-10-27 06:46:55,761     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:46:55,766     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:46:55,779     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 06:46:55,781     INFO  MainProcess  MainThread Added gid0 to subset
# 2024-10-27 06:46:55,782     INFO  MainProcess  MainThread Added first four glyphs to subset
# 2024-10-27 06:46:55,783     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 30 glyphs before
# 2024-10-27 06:46:55,785     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 06:46:55,787     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 06:46:55,792     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 30 glyphs after
# 2024-10-27 06:46:55,793     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 06:46:55,794     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 06:46:55,795     INFO  MainProcess  MainThread Closing glyph list over 'MATH': 30 glyphs before
# 2024-10-27 06:46:55,796     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 06:46:55,797     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 06:46:55,799     INFO  MainProcess  MainThread Closed glyph list over 'MATH': 30 glyphs after
# 2024-10-27 06:46:55,800     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 06:46:55,801     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 06:46:55,801     INFO  MainProcess  MainThread Closing glyph list over 'glyf': 30 glyphs before
# 2024-10-27 06:46:55,802     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 06:46:55,803     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 06:46:55,803     INFO  MainProcess  MainThread Closed glyph list over 'glyf': 30 glyphs after
# 2024-10-27 06:46:55,804     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 06:46:55,805     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 06:46:55,806     INFO  MainProcess  MainThread Retaining 30 glyphs
# 2024-10-27 06:46:55,808     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 06:46:55,809     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 06:46:55,809     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 06:46:55,810     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 06:46:55,821     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 06:46:55,825     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 06:46:55,826     INFO  MainProcess  MainThread fpgm subsetting not needed
# 2024-10-27 06:46:55,827     INFO  MainProcess  MainThread prep subsetting not needed
# 2024-10-27 06:46:55,827     INFO  MainProcess  MainThread cvt  subsetting not needed
# 2024-10-27 06:46:55,828     INFO  MainProcess  MainThread loca subsetting not needed
# 2024-10-27 06:46:55,829     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 06:46:55,830     INFO  MainProcess  MainThread gasp subsetting not needed
# 2024-10-27 06:46:55,831     INFO  MainProcess  MainThread MATH subsetted
# 2024-10-27 06:46:55,834     INFO  MainProcess  MainThread GDEF subsetted
# 2024-10-27 06:46:55,874     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 06:46:55,877     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 06:46:55,878     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 06:46:55,880     INFO  MainProcess  MainThread glyf subsetted
# 2024-10-27 06:46:55,882     INFO  MainProcess  MainThread head pruned
# 2024-10-27 06:46:55,883     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 06:46:55,884     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 06:46:55,885     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 06:46:55,885     INFO  MainProcess  MainThread GDEF pruned
# 2024-10-27 06:46:55,886     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:46:55,888     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:46:55,896     INFO  MainProcess  MainThread name pruned
# 2024-10-27 06:46:55,908     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 06:46:55,913     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 06:46:55,914     INFO  MainProcess  MainThread post pruned
# 2024-10-27 06:46:55,916     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 06:46:55,919     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:46:55,927     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:46:55,928     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 06:46:55,929     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 37 glyphs before
# 2024-10-27 06:46:55,930     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'M', 'N', 'V', 'a', 'c', 'd', 'e', 'eight', 'f', 'five', 'four', 'h', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'zero']
# 2024-10-27 06:46:55,931     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 51, 52, 55, 56, 57, 58, 63, 64, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 89, 97, 99, 101, 102, 104, 106, 107, 108, 110, 112, 122]
# 2024-10-27 06:46:55,932     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 43 glyphs after
# 2024-10-27 06:46:55,933     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'M', 'N', 'V', 'a', 'c', 'd', 'e', 'eight', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'h', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'zero']
# 2024-10-27 06:46:55,934     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 51, 52, 55, 56, 57, 58, 63, 64, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 89, 97, 99, 101, 102, 104, 106, 107, 108, 110, 112, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 06:46:55,934     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 43 glyphs before
# 2024-10-27 06:46:55,935     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'M', 'N', 'V', 'a', 'c', 'd', 'e', 'eight', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'h', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'zero']
# 2024-10-27 06:46:55,936     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 51, 52, 55, 56, 57, 58, 63, 64, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 89, 97, 99, 101, 102, 104, 106, 107, 108, 110, 112, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 06:46:55,941     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 43 glyphs after
# 2024-10-27 06:46:55,942     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'M', 'N', 'V', 'a', 'c', 'd', 'e', 'eight', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'h', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'zero']
# 2024-10-27 06:46:55,943     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 51, 52, 55, 56, 57, 58, 63, 64, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 89, 97, 99, 101, 102, 104, 106, 107, 108, 110, 112, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 06:46:55,944     INFO  MainProcess  MainThread Retaining 43 glyphs
# 2024-10-27 06:46:55,945     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 06:46:55,946     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 06:46:55,947     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 06:46:55,948     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 06:46:55,949     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 06:46:55,950     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 06:46:55,952     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 06:46:55,954     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 06:46:55,977     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 06:46:55,979     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 06:46:55,980     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 06:46:55,981     INFO  MainProcess  MainThread head pruned
# 2024-10-27 06:46:55,983     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 06:46:55,991     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 06:46:55,998     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 06:46:55,999     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:46:56,000     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:46:56,014     INFO  MainProcess  MainThread name pruned
# 2024-10-27 06:46:56,130     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_test_final/injury_criteria_box_and_rug

# %%
def plot_selection(n_largest: int = 10):
    inj2channels = {
        "Chest_Deflection": ["03CHST0000OCCUDSXD"],
        "Femur_Fz_Max_Compression": ["03FEMRRI00OCCUFOZD", "03FEMRLE00OCCUFOZD"],
        "Femur_Fz_Max_Tension": ["03FEMRRI00OCCUFOZD", "03FEMRLE00OCCUFOZD"],
        "Femur_Fz_Max": ["03FEMRRI00OCCUFOZD", "03FEMRLE00OCCUFOZD"],
        "Head_HIC15": ["03HEAD0000OCCUACXD", "03HEAD0000OCCUACYD", "03HEAD0000OCCUACZD", "03HEAD0000OCCUACRD"],
        "Head_HIC36": ["03HEAD0000OCCUACXD", "03HEAD0000OCCUACYD", "03HEAD0000OCCUACZD", "03HEAD0000OCCUACRD"],
        "Head_a3ms": ["03HEAD0000OCCUACXD", "03HEAD0000OCCUACYD", "03HEAD0000OCCUACZD", "03HEAD0000OCCUACRD"],
        "Chest_a3ms": ["03CHST0000OCCUACXD", "03CHST0000OCCUACYD", "03CHST0000OCCUACZD", "03CHST0000OCCUACRD"],
        "Neck_Fx_Shear_Max": ["03NECKUP00OCCUFOXD"],
        "Neck_Fz_Max_Tension": ["03NECKUP00OCCUFOZD"],
        "Neck_Fz_Max_Compression": ["03NECKUP00OCCUFOZD"],
        "Neck_My_Max": ["03NECKUP00OCCUMOYD"],
        "Neck_My_Extension": ["03NECKUP00OCCUMOYD"],
        "Neck_Nij": ["03NECKUP00OCCUMOYD", "03NECKUP00OCCUFOZD"],
    }
    WIDTH
    percs = [5, 50, 95]
    inj_names = sorted(set(pq.read_table(INJ_FPATH).schema.names) - {STR.perc, STR.id})
    versions = list(product(inj_names, percs))
    for inj_name, perc in tqdm(versions):
        if inj_name not in INJ_NAMES or inj_name not in inj2channels:
            continue
        db: pd.DataFrame = pd.read_parquet(INJ_FPATH, columns=[inj_name], filters=[(STR.perc, "==", perc)])[inj_name]
        ids = db.nlargest(n_largest).index.get_level_values(STR.id).to_list()

        channel_data = pd.read_parquet(
            DATA_DIR / "channels.parquet",
            columns=inj2channels[inj_name],
            filters=[(STR.id, "in", ids), (STR.perc, "==", perc)],
        ).sort_values(by=STR.time)

        fig, ax = plt.subplot_mosaic(
            mosaic=[["distro"] * len(inj2channels[inj_name]), sorted(inj2channels[inj_name])],
            # sharex="row",
            # sharey="row",
            layout="constrained",
            figsize=(WIDTH, 0.6*WIDTH),
            height_ratios=[0.2, 0.8],
        )
        fig.suptitle(f"{INJ_NAMES[inj_name]} - HIII {perc:02d} {'F' if perc == 5 else 'M'}")
        single_box_and_rug(inj_val=inj_name, perc=perc, ax=ax["distro"])
        ax["distro"].set_xlabel("")
        for ch in inj2channels[inj_name]:
            for idx in ids:
                f = channel_data.loc[(slice(None), idx), ch]
                ax[ch].plot(f.index.get_level_values(STR.time), f, label=int(idx))
            ax[ch].grid()
            ax[ch].set_ylabel(ch)
            ax[ch].set_xlabel(STR.time)
        ax[inj2channels[inj_name][-1]].legend()
        save_fig(fig=fig, f_name=f"{inj_name}_HIII{perc:02d}_{n_largest}_largest_channels")


plot_selection()
# Out:
#   0%|          | 0/48 [00:00<?, ?it/s]2024-10-27 06:46:56,991     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 06:46:56,996     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 06:46:56,997     INFO  MainProcess  MainThread post pruned
# 2024-10-27 06:46:56,999     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 06:46:57,002     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:46:57,014     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:46:57,015     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 06:46:57,017     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 20 glyphs before
# 2024-10-27 06:46:57,018     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'c', 'e', 'f', 'five', 'h', 'hyphen', 'i', 'l', 'n', 'o', 's', 'space', 't', 'zero']
# 2024-10-27 06:46:57,019     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 44, 47, 51, 55, 56, 57, 63, 64, 65, 66, 67, 73, 78, 82, 99, 104, 106, 122]
# 2024-10-27 06:46:57,021     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 25 glyphs after
# 2024-10-27 06:46:57,022     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'five', 'h', 'hyphen', 'i', 'l', 'n', 'o', 's', 'space', 't', 'zero']
# 2024-10-27 06:46:57,023     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 44, 47, 51, 55, 56, 57, 63, 64, 65, 66, 67, 73, 78, 82, 99, 104, 106, 122, 123, 124, 125, 126, 127]
# 2024-10-27 06:46:57,024     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 25 glyphs before
# 2024-10-27 06:46:57,024     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'five', 'h', 'hyphen', 'i', 'l', 'n', 'o', 's', 'space', 't', 'zero']
# 2024-10-27 06:46:57,025     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 44, 47, 51,
INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 06:47:00,452     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 06:47:00,453     INFO  MainProcess  MainThread kern dropped
# 2024-10-27 06:47:00,454     INFO  MainProcess  MainThread post pruned
# 2024-10-27 06:47:00,455     INFO  MainProcess  MainThread FFTM dropped
# 2024-10-27 06:47:00,458     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:47:00,464     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:47:00,475     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 06:47:00,477     INFO  MainProcess  MainThread Added gid0 to subset
# 2024-10-27 06:47:00,478     INFO  MainProcess  MainThread Added first four glyphs to subset
# 2024-10-27 06:47:00,480     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 8 glyphs before
# 2024-10-27 06:47:00,480     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 06:47:00,483     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 06:47:00,485     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 8 glyphs after
# 2024-10-27 06:47:00,486     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 06:47:00,487     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 06:47:00,487     INFO  MainProcess  MainThread Closing glyph list over 'MATH': 8 glyphs before
# 2024-10-27 06:47:00,488     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 06:47:00,489     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 06:47:00,490     INFO  MainProcess  MainThread Closed glyph list over 'MATH': 8 glyphs after
# 2024-10-27 06:47:00,491     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 06:47:00,491     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 06:47:00,492     INFO  MainProcess  MainThread Closing glyph list over 'glyf': 8 glyphs before
# 2024-10-27 06:47:00,493     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 06:47:00,493     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 06:47:00,494     INFO  MainProcess  MainThread Closed glyph list over 'glyf': 8 glyphs after
# 2024-10-27 06:47:00,495     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 06:47:00,496     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 06:47:00,497     INFO  MainProcess  MainThread Retaining 8 glyphs
# 2024-10-27 06:47:00,498     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 06:47:00,499     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 06:47:00,499     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 06:47:00,500     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 06:47:00,512     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 06:47:00,516     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 06:47:00,517     INFO  MainProcess  MainThread fpgm subsetting not needed
# 2024-10-27 06:47:00,518     INFO  MainProcess  MainThread prep subsetting not needed
# 2024-10-27 06:47:00,519     INFO  MainProcess  MainThread cvt  subsetting not needed
# 2024-10-27 06:47:00,520     INFO  MainProcess  MainThread loca subsetting not needed
# 2024-10-27 06:47:00,521     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 06:47:00,521     INFO  MainProcess  MainThread gasp subsetting not needed
# 2024-10-27 06:47:00,522     INFO  MainProcess  MainThread MATH subsetted
# 2024-10-27 06:47:00,526     INFO  MainProcess  MainThread GDEF subsetted
# 2024-10-27 06:47:00,562     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 06:47:00,564     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 06:47:00,565     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 06:47:00,568     INFO  MainProcess  MainThread glyf subsetted
# 2024-10-27 06:47:00,569     INFO  MainProcess  MainThread head pruned
# 2024-10-27 06:47:00,569     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 06:47:00,570     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 06:47:00,571     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 06:47:00,572     INFO  MainProcess  MainThread GDEF pruned
# 2024-10-27 06:47:00,572     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:47:00,573     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:47:00,576     INFO  MainProcess  MainThread name pruned
# 2024-10-27 06:47:00,586     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 06:47:00,591     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 06:47:00,592     INFO  MainProcess  MainThread post pruned
# 2024-10-27 06:47:00,594     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 06:47:00,596     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:47:00,605     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:47:00,606     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 06:47:00,607     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 13 glyphs before
# 2024-10-27 06:47:00,608     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'F', 'H', 'I', 'e', 'five', 'h', 'hyphen', 's', 'space', 't', 'zero']
# 2024-10-27 06:47:00,608     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 51, 55, 57, 63, 64, 65, 66, 99, 104, 106, 122]
# 2024-10-27 06:47:00,610     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 13 glyphs after
# 2024-10-27 06:47:00,611     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 
INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_test_final/Chest_a3ms_HIII05_10_largest_channels
#  15%|█▍        | 7/48 [00:04<00:22,  1.82it/s]2024-10-27 06:47:01,931     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 06:47:01,945     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 06:47:01,946     INFO  MainProcess  MainThread kern dropped
# 2024-10-27 06:47:01,947     INFO  MainProcess  MainThread post pruned
# 2024-10-27 06:47:01,948     INFO  MainProcess  MainThread FFTM dropped
# 2024-10-27 06:47:01,952     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:47:01,957     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:47:01,967     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 06:47:01,969     INFO  MainProcess  MainThread Added gid0 to subset
# 2024-10-27 06:47:01,970     INFO  MainProcess  MainThread Added first four glyphs to subset
# 2024-10-27 06:47:01,972     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 8 glyphs before
# 2024-10-27 06:47:01,973     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 06:47:01,976     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 06:47:01,979     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 8 glyphs after
# 2024-10-27 06:47:01,980     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 06:47:01,981     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 06:47:01,982     INFO  MainProcess  MainThread Closing glyph list over 'MATH': 8 glyphs before
# 2024-10-27 06:47:01,982     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 06:47:01,983     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 06:47:01,985     INFO  MainProcess  MainThread Closed glyph list over 'MATH': 8 glyphs after
# 2024-10-27 06:47:01,985     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 06:47:01,986     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 06:47:01,987     INFO  MainProcess  MainThread Closing glyph list over 'glyf': 8 glyphs before
# 2024-10-27 06:47:01,988     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 06:47:01,989     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 06:47:01,989     INFO  MainProcess  MainThread Closed glyph list over 'glyf': 8 glyphs after
# 2024-10-27 06:47:01,990     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 06:47:01,991     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 06:47:01,992     INFO  MainProcess  MainThread Retaining 8 glyphs
# 2024-10-27 06:47:01,993     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 06:47:01,994     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 06:47:01,994     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 06:47:01,995     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 06:47:02,000     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 06:47:02,009     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 06:47:02,010     INFO  MainProcess  MainThread fpgm subsetting not needed
# 2024-10-27 06:47:02,011     INFO  MainProcess  MainThread prep subsetting not needed
# 2024-10-27 06:47:02,012     INFO  MainProcess  MainThread cvt  subsetting not needed
# 2024-10-27 06:47:02,013     INFO  MainProcess  MainThread loca subsetting not needed
# 2024-10-27 06:47:02,014     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 06:47:02,014     INFO  MainProcess  MainThread gasp subsetting not needed
# 2024-10-27 06:47:02,020     INFO  MainProcess  MainThread MATH subsetted
# 2024-10-27 06:47:02,036     INFO  MainProcess  MainThread GDEF subsetted
# 2024-10-27 06:47:02,099     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 06:47:02,101     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 06:47:02,102     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 06:47:02,105     INFO  MainProcess  MainThread glyf subsetted
# 2024-10-27 06:47:02,106     INFO  MainProcess  MainThread head pruned
# 2024-10-27 06:47:02,107     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 06:47:02,108     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 06:47:02,109     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 06:47:02,109     INFO  MainProcess  MainThread GDEF pruned
# 2024-10-27 06:47:02,110     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:47:02,111     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:47:02,113     INFO  MainProcess  MainThread name pruned
# 2024-10-27 06:47:02,123     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 06:47:02,128     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 06:47:02,129     INFO  MainProcess  MainThread post pruned
# 2024-10-27 06:47:02,131     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 06:47:02,134     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:47:02,143     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:47:02,144     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 06:47:02,145     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 13 glyphs before
# 2024-10-27 06:47:02,146     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'H', 'I', 'M', 'e', 'five', 'h', 'hyphen', 's', 'space', 't', 'zero']
# 2024-10-27 06:47:02,147     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 51, 57, 63, 64, 65, 66, 75, 99, 104, 106, 122]
# 2024-10-27 06:47:02,148     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 13 glyphs after
# 2024-10-27 06:47:02,148     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'H', 'I', 'M', 'e', 'five', 'h', 'hyphen', 's', 'space', 't', 'zero']
# 2024-10-27 06:47:02,149     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 51, 57, 63, 64, 65, 66, 75, 99, 104, 106, 122]
# 2024-10-27 06:47:02,150     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 13 glyphs before
# 2024-10-27 06:47:02,150     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'H', 'I', 'M', 'e', 'five', 'h', 'hyphen', 's', 'space', 't', 'zero']
# 2024-10-27 06:47:02,151     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 51, 57, 63, 64, 65, 66, 75, 99, 104, 106, 122]
# 2024-10-27 06:47:02,153     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 13 glyphs after
# 2024-10-27 06:47:02,153     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'H', 'I', 'M', 'e', 'five', 'h', 'hyphen', 's', 'space', 't', 'zero']
# 2024-10-27 06:47:02,154     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 51, 57, 63, 64, 65, 66, 75, 99, 104, 106, 122]
# 2024-10-27 06:47:02,155     INFO  MainProcess  MainThread Retaining 13 glyphs
# 2024-10-27 06:47:02,155     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 06:47:02,156     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 06:47:02,157     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 06:47:02,158     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 06:47:02,159     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 06:47:02,159     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 06:47:02,160     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 06:47:02,162     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 06:47:02,167     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 06:47:02,169     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 06:47:02,170     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 06:47:02,171     INFO  MainProcess  MainThread head pruned
# 2024-10-27 06:47:02,172     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 06:47:02,173     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 06:47:02,176     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 06:47:02,177     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:47:02,178     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:47:02,181     INFO  MainProcess  MainThread name pruned
# 2024-10-27 06:47:02,194     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 06:47:02,202     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 06:47:02,204     INFO  MainProcess  MainThread post pruned
# 2024-10-27 06:47:02,206     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 06:47:02,209     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:47:02,220     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:47:02,221     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 06:47:02,222     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 27 glyphs before
# 2024-10-27 06:47:02,224     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'C', 'D', 'E', 'H', 'I', 'M', 'O', 'R', 'S', 'T', 'U', 'X', 'Y', 'Z', 'eight', 'five', 'four', 'minus', 'nine', 'one', 'seven', 'six', 'three', 'two', 'zero']
# 2024-10-27 06:47:02,225     INFO  MainProcess  MainThread Glyph IDs:   [0, 28, 43, 47, 50, 52, 57, 58, 63, 66, 75, 79, 81, 83, 96, 98, 101, 102, 105, 107, 108, 109, 116, 118, 120, 122, 419]
# 2024-10-27 06:47:02,227     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 27 glyphs after
# 2024-10-27 06:47:02,228     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'C', 'D', 'E', 'H', 'I', 'M', 'O', 'R', 'S', 'T', 'U', 'X', 'Y', 'Z', 'eight', 'five', 'four', 'minus', 'nine', 'one', 'seven', 'six', 'three', 'two', 'zero']
# 2024-10-27 06:47:02,229     INFO  MainProcess  MainThread Glyph IDs:   [0, 28, 43, 47, 50, 52, 57, 58, 63, 66, 75, 79, 81, 83, 96, 98, 101, 102, 105, 107, 108, 109, 116, 118, 120, 122, 419]
# 2024-10-27 06:47:02,229     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 27 glyphs before
# 2024-10-27 06:47:02,230     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'C', 'D', 'E', 'H', 'I', 'M', 'O', 'R', 'S', 'T', 'U', 'X', 'Y', 'Z', 'eight', 'five', 'four', 'minus', 'nine', 'one', 'seven', 'six', 'three', 'two', 'zero']
# ...
# 2024-10-27 06:47:26,409     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 24 glyphs before
# 2024-10-27 06:47:26,410     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'I', 'K', 'M', 'N', 'O', 'P', 'T', 'U', 'Y', 'eight', 'five', 'four', 'minus', 'nine', 'one', 'seven', 'six', 'three', 'two', 'zero']
# 2024-10-27 06:47:26,411     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 47, 50, 52, 57, 58, 66, 70, 75, 77, 79, 81, 83, 84, 101, 102, 105, 107, 108, 109, 118, 122, 419]
# 2024-10-27 06:47:26,414     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 24 glyphs after
# 2024-10-27 06:47:26,415     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'I', 'K', 'M', 'N', 'O', 'P', 'T', 'U', 'Y', 'eight', 'five', 'four', 'minus', 'nine', 'one', 'seven', 'six', 'three', 'two', 'zero']
# 2024-10-27 06:47:26,416     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 47, 50, 52, 57, 58, 66, 70, 75, 77, 79, 81, 83, 84, 101, 102, 105, 107, 108, 109, 118, 122, 419]
# 2024-10-27 06:47:26,417     INFO  MainProcess  MainThread Retaining 24 glyphs
# 2024-10-27 06:47:26,419     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 06:47:26,420     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 06:47:26,420     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 06:47:26,421     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 06:47:26,422     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 06:47:26,423     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 06:47:26,424     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 06:47:26,433     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 06:47:26,457     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 06:47:26,459     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 06:47:26,460     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 06:47:26,462     INFO  MainProcess  MainThread head pruned
# 2024-10-27 06:47:26,463     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 06:47:26,464     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 06:47:26,468     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 06:47:26,469     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:47:26,476     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:47:26,480     INFO  MainProcess  MainThread name pruned
# 2024-10-27 06:47:26,499     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_test_final/Neck_My_Extension_HIII50_10_largest_channels
#  79%|███████▉  | 38/48 [00:30<00:09,  1.06it/s]2024-10-27 06:47:27,190     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 06:47:27,204     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 06:47:27,205     INFO  MainProcess  MainThread kern dropped
# 2024-10-27 06:47:27,206     INFO  MainProcess  MainThread post pruned
# 2024-10-27 06:47:27,207     INFO  MainProcess  MainThread FFTM dropped
# 2024-10-27 06:47:27,210     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:47:27,215     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:47:27,228     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 06:47:27,230     INFO  MainProcess  MainThread Added gid0 to subset
# 2024-10-27 06:47:27,231     INFO  MainProcess  MainThread Added first four glyphs to subset
# 2024-10-27 06:47:27,232     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 15 glyphs before
# 2024-10-27 06:47:27,232     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'E', 'M', 'comma', 'e', 'i', 'n', 'nonmarkingreturn', 'o', 's', 'space', 't', 'x', 'y']
# 2024-10-27 06:47:27,235     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 40, 48, 72, 76, 81, 82, 86, 87, 91, 92]
# 2024-10-27 06:47:27,241     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 15 glyphs after
# 2024-10-27 06:47:27,241     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'E', 'M', 'comma', 'e', 'i', 'n', 'nonmarkingreturn', 'o', 's', 'space', 't', 'x', 'y']
# 2024-10-27 06:47:27,242     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 40, 48, 72, 76, 81, 82, 86, 87, 91, 92]
# 2024-10-27 06:47:27,243     INFO  MainProcess  MainThread Closing glyph list over 'MATH': 15 glyphs before
# 2024-10-27 06:47:27,244     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'E', 'M', 'comma', 'e', 'i', 'n', 'nonmarkingreturn', 'o', 's', 'space', 't', 'x', 'y']
# 2024-10-27 06:47:27,245     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 40, 48, 72, 76, 81, 82, 86, 87, 91, 92]
# 2024-10-27 06:47:27,490     INFO  MainProcess  MainThread Closed glyph list over 'MATH': 15 glyphs after
# 2024-10-27 06:47:27,491     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'E', 'M', 'comma', 'e', 'i', 'n', 'nonmarkingreturn', 'o', 's', 'space', 't', 'x', 'y']
# 2024-10-27 06:47:27,492     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 40, 48, 72, 76, 81, 82, 86, 87, 91, 92]
# 2024-10-27 06:47:27,493     INFO  MainProcess  MainThread Closing glyph list over 'glyf': 15 glyphs before
# 2024-10-27 06:47:27,493     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'E', 'M', 'comma', 'e', 'i', 'n', 'nonmarkingreturn', 'o', 's', 'space', 't', 'x', 'y']
# 2024-10-27 06:47:27,494     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 40, 48, 72, 76, 81, 82, 86, 87, 91, 92]
# 2024-10-27 06:47:27,495     INFO  MainProcess  MainThread Closed glyph list over 'glyf': 15 glyphs after
# 2024-10-27 06:47:27,496     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'E', 'M', 'comma', 'e', 'i', 'n', 'nonmarkingreturn', 'o', 's', 'space', 't', 'x', 'y']
# 2024-10-27 06:47:27,497     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 40, 48, 72, 76, 81, 82, 86, 87, 91, 92]
# 2024-10-27 06:47:27,498     INFO  MainProcess  MainThread Retaining 15 glyphs
# 2024-10-27 06:47:27,499     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 06:47:27,500     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 06:47:27,500     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 06:47:27,501     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 06:47:27,507     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 06:47:27,511     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 06:47:27,513     INFO  MainProcess  MainThread fpgm subsetting not needed
# 2024-10-27 06:47:27,514     INFO  MainProcess  MainThread prep subsetting not needed
# 2024-10-27 06:47:27,515     INFO  MainProcess  MainThread cvt  subsetting not needed
# 2024-10-27 06:47:27,516     INFO  MainProcess  MainThread loca subsetting not needed
# 2024-10-27 06:47:27,516     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 06:47:27,517     INFO  MainProcess  MainThread gasp subsetting not needed
# 2024-10-27 06:47:27,518     INFO  MainProcess  MainThread MATH subsetted
# 2024-10-27 06:47:27,523     INFO  MainProcess  MainThread GDEF subsetted
# 2024-10-27 06:47:27,574     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 06:47:27,577     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 06:47:27,578     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 06:47:27,581     INFO  MainProcess  MainThread glyf subsetted
# 2024-10-27 06:47:27,582     INFO  MainProcess  MainThread head pruned
# 2024-10-27 06:47:27,582     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 06:47:27,583     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 06:47:27,584     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 06:47:27,585     INFO  MainProcess  MainThread GDEF pruned
# 2024-10-27 06:47:27,585     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:47:27,586     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:47:27,590     INFO  MainProcess  MainThread name pruned
# 2024-10-27 06:47:27,600     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 06:47:27,605     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 06:47:27,607     INFO  MainProcess  MainThread post pruned
# 2024-10-27 06:47:27,608     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 06:47:27,611     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:47:27,619     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:47:27,621     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 06:47:27,622     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 12 glyphs before
# 2024-10-27 06:47:27,623     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'H', 'I', 'M', 'N', 'c', 'e', 'five', 'hyphen', 'k', 'nine', 'space']
# 2024-10-27 06:47:27,624     INFO  MainProcess  MainThread Glyph IDs:   [0, 44, 51, 57, 63, 65, 66, 71, 75, 77, 79, 104]
# 2024-10-27 06:47:27,625     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 12 glyphs after
# 2024-10-27 06:47:27,626     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'H', 'I', 'M', 'N', 'c', 'e', 'five', 'hyphen', 'k', 'nine', 'space']
# 2024-10-27 06:47:27,628     INFO  MainProcess  MainThread Glyph IDs:   [0, 44, 51, 57, 63, 65, 66, 71, 75, 77, 79, 104]
# 2024-10-27 06:47:27,629     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 12 glyphs before
# 2024-10-27 06:47:27,629     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'H', 'I', 'M', 'N', 'c', 'e', 'five', 'hyphen', 'k', 'nine', 'space']
# 2024-10-27 06:47:27,630     INFO  MainProcess  MainThread Glyph IDs:   [0, 44, 51, 57, 63, 65, 66, 71, 75, 77, 79, 104]
# 2024-10-27 06:47:27,632     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 12 glyphs after
# 2024-10-27 06:47:27,633     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'H', 'I', 'M', 'N', 'c', 'e', 'five', 'hyphen', 'k', 'nine', 'space']
# 2024-10-27 06:47:27,634     INFO  MainProcess  MainThread Glyph IDs:   [0, 44, 51, 57, 63, 65, 66, 71, 75, 77, 79, 104]
# 2024-10-27 06:47:27,634     INFO  MainProcess  MainThread Retaining 12 glyphs
# 2024-10-27 06:47:27,635     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 06:47:27,640     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 06:47:27,640     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 06:47:27,641     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 06:47:27,642     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 06:47:27,643     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 06:47:27,644     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 06:47:27,647     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 06:47:27,652     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 06:47:27,654     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 06:47:27,655     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 06:47:27,657     INFO  MainProcess  MainThread head pruned
# 2024-10-27 06:47:27,658     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 06:47:27,659     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 06:47:27,662     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 06:47:27,664     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:47:27,665     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:47:27,666     INFO  MainProcess  MainThread name pruned
# 2024-10-27 06:47:27,675     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 06:47:27,679     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 06:47:27,680     INFO  MainProcess  MainThread post pruned
# 2024-10-27 06:47:27,682     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 06:47:27,685     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:47:27,700     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:47:27,702     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 06:47:27,703     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 24 glyphs before
# 2024-10-27 06:47:27,704     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'I', 'K', 'M', 'N', 'O', 'P', 'T', 'U', 'Y', 'eight', 'five', 'four', 'minus', 'nine', 'one', 'seven', 'six', 'three', 'two', 'zero']
# 2024-10-27 06:47:27,705     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 47, 50, 52, 57, 58, 66, 70, 75, 77, 79, 81, 83, 84, 101, 102, 105, 107, 108, 109, 118, 122, 419]
# 2024-10-27 06:47:27,707     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 24 glyphs after
# 2024-10-27 06:47:27,707     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'I', 'K', 'M', 'N', 'O', 'P', 'T', 'U', 'Y', 'eight', 'five', 'four', 'minus', 'nine', 'one', 'seven', 'six', 'three', 'two', 'zero']
# 2024-10-27 06:47:27,710     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 47, 50, 52, 57, 58, 66, 70, 75, 77, 79, 81, 83, 84, 101, 102, 105, 107, 108, 109, 118, 122, 419]
# 2024-10-27 06:47:27,711     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 24 glyphs before
# 2024-10-27 06:47:27,712     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'I', 'K', 'M', 'N', 'O', 'P', 'T', 'U', 'Y', 'eight', 'five', 'four', 'minus', 'nine', 'one', 'seven', 'six', 'three', 'two', 'zero']
# 2024-10-27 06:47:27,713     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 47, 50, 52, 57, 58, 66, 70, 75, 77, 79, 81, 83, 84, 101, 102, 105, 107, 108, 109, 118, 122, 419]
# 2024-10-27 06:47:27,716     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 24 glyphs after
# 2024-10-27 06:47:27,717     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'I', 'K', 'M', 'N', 'O', 'P', 'T', 'U', 'Y', 'eight', 'five', 'four', 'minus', 'nine', 'one', 'seven', 'six', 'three', 'two', 'zero']
# 2024-10-27 06:47:27,718     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 47, 50, 52, 57, 58, 66, 70, 75, 77, 79, 81, 83, 84, 101, 102, 105, 107, 108, 109, 118, 122, 419]
# 2024-10-27 06:47:27,719     INFO  MainProcess  MainThread Retaining 24 glyphs
# 2024-10-27 06:47:27,720     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 06:47:27,723     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 06:47:27,724     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 06:47:27,725     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 06:47:27,726     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 06:47:27,727     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 06:47:27,729     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 06:47:27,734     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 06:47:27,748     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 06:47:27,749     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 06:47:27,750     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 06:47:27,751     INFO  MainProcess  MainThread head pruned
# 2024-10-27 06:47:27,752     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 06:47:27,753     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 06:47:27,758     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 06:47:27,760     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:47:27,761     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:47:27,764     INFO  MainProcess  MainThread name pruned
# 2024-10-27 06:47:27,778     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_test_final/Neck_My_Extension_HIII95_10_largest_channels
# 100%|██████████| 48/48 [00:31<00:00,  1.52it/s]

# %%
DROPPED_IDS: Dict[int, List[int]] = {
    5: [8, 17, 30, 40, 42, 89, 92, 102, 118, 120, 146, 158, 187, 200, 240],
    50: [40, 92, 102, 108, 180, 192, 212, 240],
    95: [86, 102],
}
json_util.dump(obj=DROPPED_IDS, f_path=DATA_DIR / STR.fname_dropped_ids)
DROPPED_IDS
# Out:
# {5: [8, 17, 30, 40, 42, 89, 92, 102, 118, 120, 146, 158, 187, 200, 240],
#  50: [40, 92, 102, 108, 180, 192, 212, 240],
#  95: [86, 102]}

# %%
def box_and_rug_cleaned():
    percs = [5, 50, 95]
    inj_names = INJURIES

    fig_width: float = WIDTH
    fig_height: float = 1.35*WIDTH

    fig, ax = plt.subplots(
        nrows=len(inj_names),
        ncols=len(percs),
        layout="constrained",
        figsize=(fig_width, fig_height),
    )

    # plot
    versions = list(product(list(enumerate(inj_names)), list(enumerate(percs))))
    for (row, inj_val), (col, perc) in tqdm(versions):
        single_box_and_rug(inj_val=inj_val, perc=perc, ax=ax[row, col], drop_ids=DROPPED_IDS)
        ax[row, 0].set_ylabel(INJ_NAMES[inj_val])
        ax[row, col].set_xlabel("")
        ax[0, col].set_title(f"HIII {perc:02d} {'F' if perc == 5 else 'M'}")

    save_fig(fig=fig, f_name="injury_criteria_box_and_rug_cleaned")


box_and_rug_cleaned()
# Out:
# 100%|██████████| 27/27 [00:01<00:00, 16.58it/s]
# 2024-10-27 06:47:32,239     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 06:47:32,256     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 06:47:32,257     INFO  MainProcess  MainThread kern dropped
# 2024-10-27 06:47:32,258     INFO  MainProcess  MainThread post pruned
# 2024-10-27 06:47:32,259     INFO  MainProcess  MainThread FFTM dropped
# 2024-10-27 06:47:32,264     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:47:32,272     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:47:32,285     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 06:47:32,287     INFO  MainProcess  MainThread Added gid0 to subset
# 2024-10-27 06:47:32,288     INFO  MainProcess  MainThread Added first four glyphs to subset
# 2024-10-27 06:47:32,289     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 30 glyphs before
# 2024-10-27 06:47:32,290     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 06:47:32,293     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 06:47:32,299     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 30 glyphs after
# 2024-10-27 06:47:32,300     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 06:47:32,301     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 06:47:32,301     INFO  MainProcess  MainThread Closing glyph list over 'MATH': 30 glyphs before
# 2024-10-27 06:47:32,302     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 06:47:32,303     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 06:47:32,306     INFO  MainProcess  MainThread Closed glyph list over 'MATH': 30 glyphs after
# 2024-10-27 06:47:32,306     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 06:47:32,307     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 06:47:32,308     INFO  MainProcess  MainThread Closing glyph list over 'glyf': 30 glyphs before
# 2024-10-27 06:47:32,308     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 06:47:32,309     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 06:47:32,310     INFO  MainProcess  MainThread Closed glyph list over 'glyf': 30 glyphs after
# 2024-10-27 06:47:32,311     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 06:47:32,312     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 06:47:32,313     INFO  MainProcess  MainThread Retaining 30 glyphs
# 2024-10-27 06:47:32,315     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 06:47:32,315     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 06:47:32,316     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 06:47:32,317     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 06:47:32,327     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 06:47:32,331     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 06:47:32,332     INFO  MainProcess  MainThread fpgm subsetting not needed
# 2024-10-27 06:47:32,333     INFO  MainProcess  MainThread prep subsetting not needed
# 2024-10-27 06:47:32,333     INFO  MainProcess  MainThread cvt  subsetting not needed
# 2024-10-27 06:47:32,334     INFO  MainProcess  MainThread loca subsetting not needed
# 2024-10-27 06:47:32,335     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 06:47:32,335     INFO  MainProcess  MainThread gasp subsetting not needed
# 2024-10-27 06:47:32,336     INFO  MainProcess  MainThread MATH subsetted
# 2024-10-27 06:47:32,340     INFO  MainProcess  MainThread GDEF subsetted
# 2024-10-27 06:47:32,382     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 06:47:32,385     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 06:47:32,386     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 06:47:32,389     INFO  MainProcess  MainThread glyf subsetted
# 2024-10-27 06:47:32,390     INFO  MainProcess  MainThread head pruned
# 2024-10-27 06:47:32,391     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 06:47:32,391     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 06:47:32,393     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 06:47:32,394     INFO  MainProcess  MainThread GDEF pruned
# 2024-10-27 06:47:32,396     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:47:32,397     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:47:32,405     INFO  MainProcess  MainThread name pruned
# 2024-10-27 06:47:32,416     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 06:47:32,421     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 06:47:32,422     INFO  MainProcess  MainThread post pruned
# 2024-10-27 06:47:32,423     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 06:47:32,426     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:47:32,437     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:47:32,439     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 06:47:32,440     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 37 glyphs before
# 2024-10-27 06:47:32,441     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'M', 'N', 'V', 'a', 'c', 'd', 'e', 'eight', 'f', 'five', 'four', 'h', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'zero']
# 2024-10-27 06:47:32,442     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 51, 52, 55, 56, 57, 58, 63, 64, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 89, 97, 99, 101, 102, 104, 106, 107, 108, 110, 112, 122]
# 2024-10-27 06:47:32,444     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 43 glyphs after
# 2024-10-27 06:47:32,445     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'M', 'N', 'V', 'a', 'c', 'd', 'e', 'eight', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'h', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'zero']
# 2024-10-27 06:47:32,445     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 51, 52, 55, 56, 57, 58, 63, 64, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 89, 97, 99, 101, 102, 104, 106, 107, 108, 110, 112, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 06:47:32,446     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 43 glyphs before
# 2024-10-27 06:47:32,447     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'M', 'N', 'V', 'a', 'c', 'd', 'e', 'eight', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'h', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'zero']
# 2024-10-27 06:47:32,447     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 51, 52, 55, 56, 57, 58, 63, 64, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 89, 97, 99, 101, 102, 104, 106, 107, 108, 110, 112, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 06:47:32,453     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 43 glyphs after
# 2024-10-27 06:47:32,454     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'M', 'N', 'V', 'a', 'c', 'd', 'e', 'eight', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'h', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'zero']
# 2024-10-27 06:47:32,455     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 51, 52, 55, 56, 57, 58, 63, 64, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 89, 97, 99, 101, 102, 104, 106, 107, 108, 110, 112, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 06:47:32,456     INFO  MainProcess  MainThread Retaining 43 glyphs
# 2024-10-27 06:47:32,457     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 06:47:32,458     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 06:47:32,459     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 06:47:32,460     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 06:47:32,464     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 06:47:32,465     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 06:47:32,466     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 06:47:32,468     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 06:47:32,483     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 06:47:32,485     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 06:47:32,485     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 06:47:32,486     INFO  MainProcess  MainThread head pruned
# 2024-10-27 06:47:32,487     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 06:47:32,488     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 06:47:32,492     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 06:47:32,493     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:47:32,494     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:47:32,499     INFO  MainProcess  MainThread name pruned
# 2024-10-27 06:47:32,614     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_test_final/injury_criteria_box_and_rug_cleaned

# %%
def plot_dropped_grid():
    # get data
    doe = pd.read_parquet(DOE_FPATH)
    factors = sorted(doe.columns)
    parser = pd.read_parquet(SIMID2ID_FPATH).reset_index().set_index([STR.id, STR.perc])

    # plot
    fig, ax = plt.subplots(
        ncols=doe.shape[1],
        nrows=doe.shape[1] + 1,
        figsize=(WIDTH, WIDTH),
        sharex="col",
        sharey="row",
        layout="constrained",
        height_ratios=[0.1] + [1] * doe.shape[1],
    )
    gs = ax[0, 0].get_gridspec()
    for a in ax[0]:
        a.remove()
    axbig = fig.add_subplot(gs[0, :])
    axbig.axis("off")

    for i, x_axis in enumerate(factors):
        for j, y_axis in enumerate(factors):
            ax[i + 1, j].scatter(doe[y_axis], doe[x_axis], color="b", label="DoE", s=0.05)

            for q, perc in enumerate(DROPPED_IDS.keys()):
                locs = parser.loc[(DROPPED_IDS[perc], perc), :].values.flatten()
                ax[i + 1, j].scatter(
                    doe.loc[locs, y_axis],
                    doe.loc[locs, x_axis],
                    color="r",
                    label=f"Dropped HIII{perc:02d}{'F' if perc == 5 else 'M'}  n={len(DROPPED_IDS[perc])}",
                    marker=["+", "x", "*"][q],
                )
            ax[i + 1, j].grid()
            ax[i + 1, j].set_axisbelow(True)

    for i, label in enumerate(factors):
        ax[-1, i].set_xlabel(label)
        ax[i + 1, 0].set_ylabel(label)
    axbig.legend(*ax[-1, -1].get_legend_handles_labels(), ncols=4, loc="center")

    save_fig(fig=fig, f_name="doe_dropped_ids")


plot_dropped_grid()
# Out:
# 2024-10-27 06:47:39,104     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 06:47:39,109     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 06:47:39,110     INFO  MainProcess  MainThread post pruned
# 2024-10-27 06:47:39,111     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 06:47:39,113     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:47:39,123     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:47:39,124     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 06:47:39,125     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 42 glyphs before
# 2024-10-27 06:47:39,126     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'B', 'C', 'D', 'E', 'F', 'H', 'I', 'L', 'M', 'P', 'R', 'S', 'T', 'V', 'X', 'a', 'c', 'd', 'e', 'eight', 'equal', 'five', 'g', 'l', 'minus', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'space', 't', 'two', 'u', 'underscore', 'zero']
# 2024-10-27 06:47:39,127     INFO  MainProcess  MainThread Glyph IDs:   [0, 28, 29, 35, 43, 44, 47, 48, 50, 51, 52, 53, 55, 57, 60, 63, 66, 72, 73, 75, 78, 79, 82, 83, 84, 85, 89, 96, 97, 98, 99, 101, 104, 105, 106, 108, 110, 111, 112, 116, 122, 419]
# 2024-10-27 06:47:39,129     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 42 glyphs after
# 2024-10-27 06:47:39,132     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'B', 'C', 'D', 'E', 'F', 'H', 'I', 'L', 'M', 'P', 'R', 'S', 'T', 'V', 'X', 'a', 'c', 'd', 'e', 'eight', 'equal', 'five', 'g', 'l', 'minus', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'space', 't', 'two', 'u', 'underscore', 'zero']
# 2024-10-27 06:47:39,133     INFO  MainProcess  MainThread Glyph IDs:   [0, 28, 29, 35, 43, 44, 47, 48, 50, 51, 52, 53, 55, 57, 60, 63, 66, 72, 73, 75, 78, 79, 82, 83, 84, 85, 89, 96, 97, 98, 99, 101, 104, 105, 106, 108, 110, 111, 112, 116, 122, 419]
# 2024-10-27 06:47:39,133     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 42 glyphs before
# 2024-10-27 06:47:39,134     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'B', 'C', 'D', 'E', 'F', 'H', 'I', 'L', 'M', 'P', 'R', 'S', 'T', 'V', 'X', 'a', 'c', 'd', 'e', 'eight', 'equal', 'five', 'g', 'l', 'minus', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'space', 't', 'two', 'u', 'underscore', 'zero']
# 2024-10-27 06:47:39,135     INFO  MainProcess  MainThread Glyph IDs:   [0, 28, 29, 35, 43, 44, 47, 48, 50, 51, 52, 53, 55, 57, 60, 63, 66, 72, 73, 75, 78, 79, 82, 83, 84, 85, 89, 96, 97, 98, 99, 101, 104, 105, 106, 108, 110, 111, 112, 116, 122, 419]
# 2024-10-27 06:47:39,141     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 42 glyphs after
# 2024-10-27 06:47:39,142     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'B', 'C', 'D', 'E', 'F', 'H', 'I', 'L', 'M', 'P', 'R', 'S', 'T', 'V', 'X', 'a', 'c', 'd', 'e', 'eight', 'equal', 'five', 'g', 'l', 'minus', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'space', 't', 'two', 'u', 'underscore', 'zero']
# 2024-10-27 06:47:39,142     INFO  MainProcess  MainThread Glyph IDs:   [0, 28, 29, 35, 43, 44, 47, 48, 50, 51, 52, 53, 55, 57, 60, 63, 66, 72, 73, 75, 78, 79, 82, 83, 84, 85, 89, 96, 97, 98, 99, 101, 104, 105, 106, 108, 110, 111, 112, 116, 122, 419]
# 2024-10-27 06:47:39,143     INFO  MainProcess  MainThread Retaining 42 glyphs
# 2024-10-27 06:47:39,144     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 06:47:39,146     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 06:47:39,146     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 06:47:39,147     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 06:47:39,148     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 06:47:39,149     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 06:47:39,150     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 06:47:39,152     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 06:47:39,178     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 06:47:39,180     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 06:47:39,181     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 06:47:39,183     INFO  MainProcess  MainThread head pruned
# 2024-10-27 06:47:39,184     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 06:47:39,185     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 06:47:39,189     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 06:47:39,190     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 06:47:39,191     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 06:47:39,196     INFO  MainProcess  MainThread name pruned
# 2024-10-27 06:47:39,228     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_test_final/doe_dropped_ids

# %%
def plot_bars(point_db: pd.DataFrame, fig_title: str, store: bool = True, sort_by_all: bool = True) -> None:
    if sort_by_all:
        existing_points = [str(x) for x in sorted(set(point_db.to_numpy().flatten()))]
    percs = sorted(point_db.index.get_level_values(STR.perc).unique())

    for perc in percs:
        for idx in DROPPED_IDS[perc]:
            try:
                point_db.drop(index=[idx, perc], inplace=True)
            except KeyError:
                LOG.warning("Could not drop index %s of perc %s", idx, perc)

    fig_width: float = WIDTH
    fig_height: float = 0.7 * fig_width
    fig, ax = plt.subplots(
        ncols=point_db.shape[1],
        nrows=len(percs),
        figsize=(fig_width, fig_height),
        sharex=True,
        sharey=True if sort_by_all else "row",
        layout="constrained",
    )
    fig.suptitle(fig_title)
    vers = list(product(list(enumerate(point_db.columns)), list(enumerate(percs))))
    for (col, val), (row, perc) in vers:
        if not sort_by_all:
            existing_points = [
                str(x)
                for x in sorted(
                    set(point_db.loc[(slice(None), perc), val].to_numpy().flatten()), key=lambda x: int(x.split(":")[0])
                )
            ]
        cnt = [str(x) for x in point_db.loc[(slice(None), perc), val].to_list()]
        sns.countplot(
            cnt,
            ax=ax[row, col],
            order=existing_points,
            alpha=0.5,
            native_scale=False,
        )
        ax[0, col].set_title(val, size="x-small")
        ax[row, 0].set_ylabel(f"HIII{perc:02} - n={len(cnt)}")
        ax[row, col].set_xlim([0, 9000])
        ax[row, col].bar_label(ax[row, col].containers[0], fontsize=7, rotation=90, padding=2)
    if store:
        save_fig(fig=fig, f_name=f"{'_'.join(fig_title.lower().split())}_distribution_bars")


plot_bars(
    point_db=pd.concat(
        [LoadForClassification(data_directory=DATA_DIR).injury_value_to_points(percentile=perc) for perc in (5, 95)], axis=0
    ),
    fig_title="Points by Euro NCAP",
    store=True,
)
# Out:
# 2024-10-27 08:11:46,584     INFO  MainProcess  MainThread Directory '/root/py_projects/aihiii/data/doe/doe_sobol_test_20240829_135200' exists
# 2024-10-27 08:11:46,587     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_sobol_test_20240829_135200/injury_criteria.parquet' exists
# 2024-10-27 08:11:46,588     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_sobol_test_20240829_135200/results_info.json' exists
# 2024-10-27 08:11:46,599     INFO  MainProcess  MainThread Hashes of injury files are the same
# 2024-10-27 08:11:46,860     INFO  MainProcess  MainThread Directory '/root/py_projects/aihiii/data/doe/doe_sobol_test_20240829_135200' exists
# 2024-10-27 08:11:46,862     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_sobol_test_20240829_135200/injury_criteria.parquet' exists
# 2024-10-27 08:11:46,863     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/doe_sobol_test_20240829_135200/results_info.json' exists
# 2024-10-27 08:11:46,868     INFO  MainProcess  MainThread Hashes of injury files are the same
# /tmp/ipykernel_3414001/3553979003.py:9: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   point_db.drop(index=[idx, perc], inplace=True)
# 2024-10-27 08:11:47,098  WARNING  MainProcess  MainThread Could not drop index 17 of perc 5.0
# 2024-10-27 08:11:47,099  WARNING  MainProcess  MainThread Could not drop index 30 of perc 5.0
# 2024-10-27 08:11:47,100  WARNING  MainProcess  MainThread Could not drop index 40 of perc 5.0
# 2024-10-27 08:11:47,101  WARNING  MainProcess  MainThread Could not drop index 42 of perc 5.0
# 2024-10-27 08:11:47,102  WARNING  MainProcess  MainThread Could not drop index 89 of perc 5.0
# 2024-10-27 08:11:47,103  WARNING  MainProcess  MainThread Could not drop index 92 of perc 5.0
# 2024-10-27 08:11:47,104  WARNING  MainProcess  MainThread Could not drop index 102 of perc 5.0
# 2024-10-27 08:11:47,105  WARNING  MainProcess  MainThread Could not drop index 118 of perc 5.0
# 2024-10-27 08:11:47,106  WARNING  MainProcess  MainThread Could not drop index 120 of perc 5.0
# 2024-10-27 08:11:47,107  WARNING  MainProcess  MainThread Could not drop index 146 of perc 5.0
# 2024-10-27 08:11:47,110  WARNING  MainProcess  MainThread Could not drop index 158 of perc 5.0
# 2024-10-27 08:11:47,111  WARNING  MainProcess  MainThread Could not drop index 187 of perc 5.0
# 2024-10-27 08:11:47,112  WARNING  MainProcess  MainThread Could not drop index 200 of perc 5.0
# 2024-10-27 08:11:47,115  WARNING  MainProcess  MainThread Could not drop index 240 of perc 5.0
# 2024-10-27 08:11:47,120  WARNING  MainProcess  MainThread Could not drop index 102 of perc 95.0
# 2024-10-27 08:11:47,596     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:47,609     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:47,691     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:47,702     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:47,771     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:47,778     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:47,845     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:47,858     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:47,918     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:47,927     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:47,980     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:47,986     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:48,042     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:48,048     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:48,102     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:48,109     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:48,164     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:48,174     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:48,233     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:48,245     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:48,290     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:48,298     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:48,350     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:48,358     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:48,419     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:48,426     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:48,476     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:48,484     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:48,531     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:48,540     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:48,589     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:48,596     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:11:50,781     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:11:50,787     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:11:50,788     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:11:50,789     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:11:50,792     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:11:50,802     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:11:50,803     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:11:50,804     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 16 glyphs before
# 2024-10-27 08:11:50,805     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'C', 'E', 'N', 'P', 'b', 'i', 'n', 'o', 'r', 's', 'space', 't', 'u', 'y']
# 2024-10-27 08:11:50,807     INFO  MainProcess  MainThread Glyph IDs:   [0, 28, 36, 43, 50, 67, 77, 78, 82, 84, 97, 99, 104, 106, 110, 119]
# 2024-10-27 08:11:50,808     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 16 glyphs after
# 2024-10-27 08:11:50,809     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'C', 'E', 'N', 'P', 'b', 'i', 'n', 'o', 'r', 's', 'space', 't', 'u', 'y']
# 2024-10-27 08:11:50,809     INFO  MainProcess  MainThread Glyph IDs:   [0, 28, 36, 43, 50, 67, 77, 78, 82, 84, 97, 99, 104, 106, 110, 119]
# 2024-10-27 08:11:50,810     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 16 glyphs before
# 2024-10-27 08:11:50,811     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'C', 'E', 'N', 'P', 'b', 'i', 'n', 'o', 'r', 's', 'space', 't', 'u', 'y']
# 2024-10-27 08:11:50,811     INFO  MainProcess  MainThread Glyph IDs:   [0, 28, 36, 43, 50, 67, 77, 78, 82, 84, 97, 99, 104, 106, 110, 119]
# 2024-10-27 08:11:50,813     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 16 glyphs after
# 2024-10-27 08:11:50,814     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'C', 'E', 'N', 'P', 'b', 'i', 'n', 'o', 'r', 's', 'space', 't', 'u', 'y']
# 2024-10-27 08:11:50,815     INFO  MainProcess  MainThread Glyph IDs:   [0, 28, 36, 43, 50, 67, 77, 78, 82, 84, 97, 99, 104, 106, 110, 119]
# 2024-10-27 08:11:50,816     INFO  MainProcess  MainThread Retaining 16 glyphs
# 2024-10-27 08:11:50,816     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:11:50,817     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:11:50,818     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:11:50,818     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:11:50,819     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:11:50,820     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:11:50,822     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:11:50,824     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:11:50,836     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:11:50,838     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:11:50,839     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:11:50,844     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:11:50,845     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:11:50,846     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:11:50,849     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:11:50,850     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:11:50,851     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:11:50,853     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:11:50,867     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:11:50,873     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:11:50,874     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:11:50,876     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:11:50,880     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:11:50,889     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:11:50,891     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:11:50,893     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 47 glyphs before
# 2024-10-27 08:11:50,894     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'S', 'T', 'V', 'a', 'c', 'd', 'e', 'eight', 'equal', 'f', 'five', 'four', 'h', 'hyphen', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:11:50,895     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 63, 64, 65, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122]
# 2024-10-27 08:11:50,897     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 53 glyphs after
# 2024-10-27 08:11:50,897     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'S', 'T', 'V', 'a', 'c', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'h', 'hyphen', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:11:50,898     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 63, 64, 65, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:11:50,899     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 53 glyphs before
# 2024-10-27 08:11:50,900     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'S', 'T', 'V', 'a', 'c', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'h', 'hyphen', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:11:50,900     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 63, 64, 65, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:11:50,906     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 53 glyphs after
# 2024-10-27 08:11:50,907     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'S', 'T', 'V', 'a', 'c', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'h', 'hyphen', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:11:50,908     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 63, 64, 65, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:11:50,909     INFO  MainProcess  MainThread Retaining 53 glyphs
# 2024-10-27 08:11:50,910     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:11:50,911     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:11:50,912     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:11:50,913     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:11:50,914     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:11:50,915     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:11:50,916     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:11:50,921     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:11:50,944     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:11:50,946     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:11:50,947     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:11:50,948     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:11:50,949     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:11:50,950     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:11:50,955     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:11:50,956     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:11:50,959     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:11:50,965     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:11:50,985     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_test_final/points_by_euro_ncap_distribution_bars

# %%
def plot_classes(n_classes: int):
    LOG.info("Plotting classes with %s classes", n_classes)
    db = pd.read_parquet(CLASSES_FPATHS[n_classes])
    db = pd.concat([db.loc[(slice(None), perc), :].replace(RENAMER[perc][n_classes]) for perc in (5, 95)], axis=0)

    plot_bars(point_db=db, fig_title=f"Classification with {n_classes} Classes", store=True, sort_by_all=False)


_ = [plot_classes(n_classes=n_classes) for n_classes in CLASSES_FPATHS.keys()]
# Out:
# 2024-10-27 08:12:11,848     INFO  MainProcess  MainThread Plotting classes with 2 classes
# /tmp/ipykernel_3414001/3553979003.py:9: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   point_db.drop(index=[idx, perc], inplace=True)
# 2024-10-27 08:12:11,872  WARNING  MainProcess  MainThread Could not drop index 17 of perc 5.0
# 2024-10-27 08:12:11,873  WARNING  MainProcess  MainThread Could not drop index 30 of perc 5.0
# 2024-10-27 08:12:11,875  WARNING  MainProcess  MainThread Could not drop index 40 of perc 5.0
# 2024-10-27 08:12:11,877  WARNING  MainProcess  MainThread Could not drop index 42 of perc 5.0
# 2024-10-27 08:12:11,879  WARNING  MainProcess  MainThread Could not drop index 89 of perc 5.0
# 2024-10-27 08:12:11,880  WARNING  MainProcess  MainThread Could not drop index 92 of perc 5.0
# 2024-10-27 08:12:11,882  WARNING  MainProcess  MainThread Could not drop index 102 of perc 5.0
# 2024-10-27 08:12:11,885  WARNING  MainProcess  MainThread Could not drop index 118 of perc 5.0
# 2024-10-27 08:12:11,886  WARNING  MainProcess  MainThread Could not drop index 120 of perc 5.0
# 2024-10-27 08:12:11,888  WARNING  MainProcess  MainThread Could not drop index 146 of perc 5.0
# 2024-10-27 08:12:11,889  WARNING  MainProcess  MainThread Could not drop index 158 of perc 5.0
# 2024-10-27 08:12:11,890  WARNING  MainProcess  MainThread Could not drop index 187 of perc 5.0
# 2024-10-27 08:12:11,891  WARNING  MainProcess  MainThread Could not drop index 200 of perc 5.0
# 2024-10-27 08:12:11,895  WARNING  MainProcess  MainThread Could not drop index 240 of perc 5.0
# 2024-10-27 08:12:11,899  WARNING  MainProcess  MainThread Could not drop index 102 of perc 95.0
# 2024-10-27 08:12:13,998     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:12:14,003     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:12:14,004     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:12:14,005     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:12:14,009     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:12:14,018     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:12:14,019     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:12:14,020     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 16 glyphs before
# 2024-10-27 08:12:14,021     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'h', 'i', 'l', 'n', 'o', 's', 'space', 't', 'two', 'w']
# 2024-10-27 08:12:14,023     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 104, 106, 108, 115]
# 2024-10-27 08:12:14,025     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 21 glyphs after
# 2024-10-27 08:12:14,026     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'space', 't', 'two', 'w']
# 2024-10-27 08:12:14,027     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 104, 106, 108, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:12:14,028     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 21 glyphs before
# 2024-10-27 08:12:14,028     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'space', 't', 'two', 'w']
# 2024-10-27 08:12:14,029     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 104, 106, 108, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:12:14,033     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 21 glyphs after
# 2024-10-27 08:12:14,033     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'space', 't', 
PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   point_db.drop(index=[idx, perc], inplace=True)
# 2024-10-27 08:12:19,215  WARNING  MainProcess  MainThread Could not drop index 17 of perc 5.0
# 2024-10-27 08:12:19,216  WARNING  MainProcess  MainThread Could not drop index 30 of perc 5.0
# 2024-10-27 08:12:19,217  WARNING  MainProcess  MainThread Could not drop index 40 of perc 5.0
# 2024-10-27 08:12:19,218  WARNING  MainProcess  MainThread Could not drop index 42 of perc 5.0
# 2024-10-27 08:12:19,219  WARNING  MainProcess  MainThread Could not drop index 89 of perc 5.0
# 2024-10-27 08:12:19,220  WARNING  MainProcess  MainThread Could not drop index 92 of perc 5.0
# 2024-10-27 08:12:19,221  WARNING  MainProcess  MainThread Could not drop index 102 of perc 5.0
# 2024-10-27 08:12:19,222  WARNING  MainProcess  MainThread Could not drop index 118 of perc 5.0
# 2024-10-27 08:12:19,224  WARNING  MainProcess  MainThread Could not drop index 120 of perc 5.0
# 2024-10-27 08:12:19,226  WARNING  MainProcess  MainThread Could not drop index 146 of perc 5.0
# 2024-10-27 08:12:19,228  WARNING  MainProcess  MainThread Could not drop index 158 of perc 5.0
# 2024-10-27 08:12:19,229  WARNING  MainProcess  MainThread Could not drop index 187 of perc 5.0
# 2024-10-27 08:12:19,230  WARNING  MainProcess  MainThread Could not drop index 200 of perc 5.0
# 2024-10-27 08:12:19,231  WARNING  MainProcess  MainThread Could not drop index 240 of perc 5.0
# 2024-10-27 08:12:19,234  WARNING  MainProcess  MainThread Could not drop index 102 of perc 95.0
# 2024-10-27 08:12:21,534     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:12:21,539     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:12:21,540     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:12:21,541     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:12:21,544     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:12:21,553     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:12:21,554     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:12:21,555     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 16 glyphs before
# 2024-10-27 08:12:21,556     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'h', 'i', 'l', 'n', 'o', 's', 'seven', 'space', 't', 'w']
# 2024-10-27 08:12:21,557     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 101, 104, 106, 115]
# 2024-10-27 08:12:21,558     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 21 glyphs after
# 2024-10-27 08:12:21,559     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'seven', 'space', 't', 'w']
# 2024-10-27 08:12:21,559     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 101, 104, 106, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:12:21,560     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 21 glyphs before
# 2024-10-27 08:12:21,560     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'seven', 'space', 't', 'w']
# 2024-10-27 08:12:21,561     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 101, 104, 106, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:12:21,564     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 21 glyphs after
# 2024-10-27 08:12:21,565     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'seven', 'space', 't', 'w']
# 2024-10-27 08:12:21,565     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 101, 104, 106, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:12:21,566     INFO  MainProcess  MainThread Retaining 21 glyphs
# 2024-10-27 08:12:21,567     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:12:21,568     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:12:21,568     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:12:21,569     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:12:21,570     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:12:21,571     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:12:21,571     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:12:21,574     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:12:21,580     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:12:21,581     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:12:21,582     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:12:21,583     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:12:21,584     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:12:21,585     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:12:21,588     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:12:21,589     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:12:21,590     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:12:21,596     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:12:21,609     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:12:21,615     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:12:21,616     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:12:21,618     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:12:21,621     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:12:21,630     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:12:21,631     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:12:21,631     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 51 glyphs before
# 2024-10-27 08:12:21,632     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:12:21,633     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122]
# 2024-10-27 08:12:21,634     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 57 glyphs after
# 2024-10-27 08:12:21,635     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:12:21,636     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:12:21,637     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 57 glyphs before
# 2024-10-27 08:12:21,637     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:12:21,638     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:12:21,645     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 57 glyphs after
# 2024-10-27 08:12:21,646     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:12:21,647     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:12:21,650     INFO  MainProcess  MainThread Retaining 57 glyphs
# 2024-10-27 08:12:21,651     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:12:21,652     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:12:21,654     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:12:21,655     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:12:21,657     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:12:21,658     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:12:21,659     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:12:21,661     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:12:21,681     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:12:21,682     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:12:21,683     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:12:21,684     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:12:21,685     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:12:21,685     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:12:21,690     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:12:21,691     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:12:21,692     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:12:21,699     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:12:21,717     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_test_final/classification_with_7_classes_distribution_bars
