# %%
import logging
import os
import sys
from itertools import product
from pathlib import Path
from typing import Dict, List, Optional

import IPython
import matplotlib
from seaborn._statistics import LetterValues
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pyarrow.parquet as pq
import seaborn as sns
import textalloc as ta
from tqdm import tqdm

NOTEBOOK_PATH: Path = Path(IPython.extract_module_locals()[1]["__vsc_ipynb_file__"])
PROJECT_DIR: Path = NOTEBOOK_PATH.parent.parent
sys.path.append(str(PROJECT_DIR))
import src.utils.custom_log as custom_log
from src._StandardNames import StandardNames
from src.load.LoadForClassification import RENAMER, LoadForClassification
from src.utils.PathChecker import PathChecker
from src.utils.set_rcparams import set_rcparams
import src.utils.json_util as json_util

os.chdir(PROJECT_DIR)
set_rcparams()

LOG: logging.Logger = logging.getLogger(__name__)
custom_log.init_logger(log_lvl=logging.INFO)
LOG.info("Log start, project directory is %s (exist: %s)", PROJECT_DIR, PROJECT_DIR.is_dir())

CHECK: PathChecker = PathChecker()
STR: StandardNames = StandardNames()

FIG_DIR: Path = CHECK.check_directory(PROJECT_DIR / "reports" / "figures", exit=False)
FIG_DIR /= NOTEBOOK_PATH.stem
FIG_DIR.mkdir(parents=True, exist_ok=True)
LOG.info("Figure directory is %s (exist: %s)", FIG_DIR, FIG_DIR.is_dir())

DATA_DIR: Path = CHECK.check_directory(PROJECT_DIR / "data" / "doe" / "virthuman", exit=False)
INJ_FPATH: Path = CHECK.check_file(DATA_DIR / "injury_criteria.parquet", exit=False)
CLASSES_FPATHS: Dict[int, Path] = {
    i: CHECK.check_file(DATA_DIR / f"injury_criteria_classes_{i}.parquet", exit=False) for i in (2, 3, 5, 7)
}
CHANNELS_FPATH: Path = CHECK.check_file(DATA_DIR / "channels.parquet", exit=False)
DOE_FPATH: Path = CHECK.check_file(DATA_DIR / "doe.parquet", exit=False)
SIMID2ID_FPATH: Path = CHECK.check_file(DATA_DIR / "sim_id_2_id.parquet", exit=False)
# Out:
# 2024-10-27 08:12:45,959     INFO  MainProcess  MainThread Log start, project directory is /root/py_projects/aihiii (exist: True)
# 2024-10-27 08:12:45,960     INFO  MainProcess  MainThread Directory '/root/py_projects/aihiii/reports/figures' exists
# 2024-10-27 08:12:45,962     INFO  MainProcess  MainThread Figure directory is /root/py_projects/aihiii/reports/figures/analyze_injury_data_virthuman_final (exist: True)
# 2024-10-27 08:12:45,963     INFO  MainProcess  MainThread Directory '/root/py_projects/aihiii/data/doe/virthuman' exists
# 2024-10-27 08:12:45,964     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/virthuman/injury_criteria.parquet' exists
# 2024-10-27 08:12:45,966     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/virthuman/injury_criteria_classes_2.parquet' exists
# 2024-10-27 08:12:45,966     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/virthuman/injury_criteria_classes_3.parquet' exists
# 2024-10-27 08:12:45,967     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/virthuman/injury_criteria_classes_5.parquet' exists
# 2024-10-27 08:12:45,968     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/virthuman/injury_criteria_classes_7.parquet' exists
# 2024-10-27 08:12:45,971     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/virthuman/channels.parquet' exists
# 2024-10-27 08:12:45,972     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/virthuman/doe.parquet' exists
# 2024-10-27 08:12:45,976     INFO  MainProcess  MainThread FileNotFoundError: /root/py_projects/aihiii/data/doe/virthuman/sim_id_2_id.parquet

# %%
INJURIES: List[str] = [
    "Head_HIC15",
    "Head_a3ms",
    "Neck_My_Extension",
    "Neck_Fz_Max_Tension",
    "Neck_Fx_Shear_Max",
    "Chest_a3ms",
    "Chest_Deflection",
    "Chest_VC",
    "Femur_Fz_Max_Compression",
]
INJ_NAMES: Dict[str, str] = {
    "Head_HIC15": "Head $\\text{HIC}_\\text{15}$",
    "Head_a3ms": "Head $\\text{a}_\\text{3ms}$",
    "Neck_My_Extension": "Neck $\\text{M}_{\\text{y, Extension}}$",
    "Neck_Fz_Max_Tension": "Neck $\\text{F}_{\\text{z, Tension}}$",
    "Neck_Fx_Shear_Max": "Neck $\\text{F}_{\\text{x, Shear}}$",
    "Chest_a3ms": "Chest $\\text{a}_\\text{3ms}$",
    "Chest_Deflection": "Chest Deflection",
    "Chest_VC": "Chest VC",
    "Femur_Fz_Max_Compression": "Femur $\\text{F}_{\\text{z, Compression}}$",
}
WIDTH = 448.13095 / 72

# %%
def save_fig(fig: matplotlib.figure.Figure, f_name: str) -> None:
    f_path = FIG_DIR / f_name
    fig.savefig(f_path.with_suffix(".pdf"), transparent=False)
    LOG.info("Saved figure to %s", f_path)
    plt.close(fig)

# %%
def single_box_and_rug(inj_val: str, perc: int, ax, drop_ids: Optional[Dict[int, List[int]]] = None):
    filters = [(STR.perc, "==", perc)]
    if drop_ids is not None:
        filters += [(STR.id, "not in", drop_ids[perc])]

    db: pd.DataFrame = pd.read_parquet(INJ_FPATH, columns=[inj_val], filters=tuple(filters))[inj_val].droplevel(STR.perc)


    # base plot
    sns.rugplot(x=db, ax=ax, height=0.05)
    sns.boxenplot(
        x=db,
        ax=ax,
        fill=False,
        color=".5",
        linecolor="#137",
        flier_kws={"s": 0.2},
    )

    # extreme outlier
    if drop_ids is None:
        q1, q3 = db.quantile([0.25, 0.75])
        iqr = q3 - q1
        db_extreme = db[db.le(q1 - 3 * iqr) | db.ge(q3 + 3 * iqr)]
        if len(db_extreme) > 0:
            ax.scatter(
                db_extreme,
                [0] * len(db_extreme),
                color="r",
                marker="x",
                s=0.7,
                alpha=0.5,
            )
        
        fliers = LetterValues(k_depth="tukey", outlier_prop=0.007, trust_alpha=0.05)(db.values)["fliers"]
        idx = pd.Index(db.values)
        idx = [int(db.index[idx.get_loc(x)]) for x in fliers]

        ta.allocate(
                ax=ax,
                y=[0] * len(fliers),
                x=fliers,
                text_list=idx,
                y_scatter=[0] * len(fliers),
                x_scatter=fliers,
                min_distance=0.1,
                linecolor="g",
                linewidth=0.2,
                textsize=5,
                avoid_label_lines_overlap=True,
            )

# %%
def box_and_rug():
    percs = [5, 50, 95]
    inj_names = INJURIES

    fig_width: float = WIDTH
    fig_height: float = 1.35*WIDTH

    fig, ax = plt.subplots(
        nrows=len(inj_names),
        ncols=len(percs),
        layout="constrained",
        figsize=(fig_width, fig_height),
    )

    # plot
    versions = list(product(list(enumerate(inj_names)), list(enumerate(percs))))
    for (row, inj_val), (col, perc) in tqdm(versions):
        single_box_and_rug(inj_val=inj_val, perc=perc, ax=ax[row, col])
        ax[row, 0].set_ylabel(INJ_NAMES[inj_val])
        ax[row, col].set_xlabel("")
        ax[0, col].set_title(f"HIII {perc:02d} {'F' if perc == 5 else 'M'}")

    save_fig(fig=fig, f_name="injury_criteria_box_and_rug")


box_and_rug()
# Out:
# 100%|██████████| 27/27 [00:50<00:00,  1.86s/it]
# 2024-10-27 08:13:40,258     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:13:40,278     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:13:40,282     INFO  MainProcess  MainThread kern dropped
# 2024-10-27 08:13:40,283     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:13:40,284     INFO  MainProcess  MainThread FFTM dropped
# 2024-10-27 08:13:40,288     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:13:40,293     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:13:40,307     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 08:13:40,309     INFO  MainProcess  MainThread Added gid0 to subset
# 2024-10-27 08:13:40,311     INFO  MainProcess  MainThread Added first four glyphs to subset
# 2024-10-27 08:13:40,312     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 30 glyphs before
# 2024-10-27 08:13:40,313     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 08:13:40,316     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 08:13:40,322     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 30 glyphs after
# 2024-10-27 08:13:40,324     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 08:13:40,327     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 08:13:40,328     INFO  MainProcess  MainThread Closing glyph list over 'MATH': 30 glyphs before
# 2024-10-27 08:13:40,328     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 08:13:40,330     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 08:13:40,333     INFO  MainProcess  MainThread Closed glyph list over 'MATH': 30 glyphs after
# 2024-10-27 08:13:40,335     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 08:13:40,337     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 08:13:40,338     INFO  MainProcess  MainThread Closing glyph list over 'glyf': 30 glyphs before
# 2024-10-27 08:13:40,339     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 08:13:40,342     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 08:13:40,343     INFO  MainProcess  MainThread Closed glyph list over 'glyf': 30 glyphs after
# 2024-10-27 08:13:40,344     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 08:13:40,345     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 08:13:40,346     INFO  MainProcess  MainThread Retaining 30 glyphs
# 2024-10-27 08:13:40,347     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:13:40,348     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:13:40,349     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:13:40,350     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:13:40,361     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:13:40,367     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:13:40,368     INFO  MainProcess  MainThread fpgm subsetting not needed
# 2024-10-27 08:13:40,370     INFO  MainProcess  MainThread prep subsetting not needed
# 2024-10-27 08:13:40,372     INFO  MainProcess  MainThread cvt  subsetting not needed
# 2024-10-27 08:13:40,374     INFO  MainProcess  MainThread loca subsetting not needed
# 2024-10-27 08:13:40,375     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:13:40,376     INFO  MainProcess  MainThread gasp subsetting not needed
# 2024-10-27 08:13:40,379     INFO  MainProcess  MainThread MATH subsetted
# 2024-10-27 08:13:40,384     INFO  MainProcess  MainThread GDEF subsetted
# 2024-10-27 08:13:40,441     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:13:40,445     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:13:40,445     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:13:40,448     INFO  MainProcess  MainThread glyf subsetted
# 2024-10-27 08:13:40,449     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:13:40,451     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:13:40,451     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:13:40,453     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 08:13:40,454     INFO  MainProcess  MainThread GDEF pruned
# 2024-10-27 08:13:40,455     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:13:40,457     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:13:40,467     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:13:40,479     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:13:40,483     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:13:40,484     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:13:40,486     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:13:40,489     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:13:40,500     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:13:40,502     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:13:40,503     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 37 glyphs before
# 2024-10-27 08:13:40,504     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'M', 'N', 'V', 'a', 'c', 'd', 'e', 'eight', 'f', 'five', 'four', 'h', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'zero']
# 2024-10-27 08:13:40,505     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 51, 52, 55, 56, 57, 58, 63, 64, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 89, 97, 99, 101, 102, 104, 106, 107, 108, 110, 112, 122]
# 2024-10-27 08:13:40,507     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 43 glyphs after
# 2024-10-27 08:13:40,508     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'M', 'N', 'V', 'a', 'c', 'd', 'e', 'eight', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'h', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'zero']
# 2024-10-27 08:13:40,509     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 51, 52, 55, 56, 57, 58, 63, 64, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 89, 97, 99, 101, 102, 104, 106, 107, 108, 110, 112, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:13:40,510     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 43 glyphs before
# 2024-10-27 08:13:40,511     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'M', 'N', 'V', 'a', 'c', 'd', 'e', 'eight', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'h', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'zero']
# 2024-10-27 08:13:40,511     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 51, 52, 55, 56, 57, 58, 63, 64, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 89, 97, 99, 101, 102, 104, 106, 107, 108, 110, 112, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:13:40,518     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 43 glyphs after
# 2024-10-27 08:13:40,520     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'M', 'N', 'V', 'a', 'c', 'd', 'e', 'eight', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'h', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'zero']
# 2024-10-27 08:13:40,521     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 51, 52, 55, 56, 57, 58, 63, 64, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 89, 97, 99, 101, 102, 104, 106, 107, 108, 110, 112, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:13:40,522     INFO  MainProcess  MainThread Retaining 43 glyphs
# 2024-10-27 08:13:40,523     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:13:40,523     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:13:40,524     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:13:40,525     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:13:40,526     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:13:40,527     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:13:40,528     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:13:40,534     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:13:40,552     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:13:40,554     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:13:40,555     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:13:40,556     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:13:40,558     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:13:40,559     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:13:40,567     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:13:40,569     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:13:40,573     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:13:40,579     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:13:40,687     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_virthuman_final/injury_criteria_box_and_rug

# %%
def plot_selection(n_largest: int = 10):
    inj2channels = {
        "Chest_Deflection": ["03CHST0000OCCUDSXD"],
        "Femur_Fz_Max_Compression": ["03FEMRRI00OCCUFOZD", "03FEMRLE00OCCUFOZD"],
        "Femur_Fz_Max_Tension": ["03FEMRRI00OCCUFOZD", "03FEMRLE00OCCUFOZD"],
        "Femur_Fz_Max": ["03FEMRRI00OCCUFOZD", "03FEMRLE00OCCUFOZD"],
        "Head_HIC15": ["03HEAD0000OCCUACXD", "03HEAD0000OCCUACYD", "03HEAD0000OCCUACZD", "03HEAD0000OCCUACRD"],
        "Head_HIC36": ["03HEAD0000OCCUACXD", "03HEAD0000OCCUACYD", "03HEAD0000OCCUACZD", "03HEAD0000OCCUACRD"],
        "Head_a3ms": ["03HEAD0000OCCUACXD", "03HEAD0000OCCUACYD", "03HEAD0000OCCUACZD", "03HEAD0000OCCUACRD"],
        "Chest_a3ms": ["03CHST0000OCCUACXD", "03CHST0000OCCUACYD", "03CHST0000OCCUACZD", "03CHST0000OCCUACRD"],
        "Neck_Fx_Shear_Max": ["03NECKUP00OCCUFOXD"],
        "Neck_Fz_Max_Tension": ["03NECKUP00OCCUFOZD"],
        "Neck_Fz_Max_Compression": ["03NECKUP00OCCUFOZD"],
        "Neck_My_Max": ["03NECKUP00OCCUMOYD"],
        "Neck_My_Extension": ["03NECKUP00OCCUMOYD"],
        "Neck_Nij": ["03NECKUP00OCCUMOYD", "03NECKUP00OCCUFOZD"],
    }
    WIDTH
    percs = [5, 50, 95]
    inj_names = sorted(set(pq.read_table(INJ_FPATH).schema.names) - {STR.perc, STR.id})
    versions = list(product(inj_names, percs))
    for inj_name, perc in tqdm(versions):
        if inj_name not in INJ_NAMES or inj_name not in inj2channels:
            continue
        db: pd.DataFrame = pd.read_parquet(INJ_FPATH, columns=[inj_name], filters=[(STR.perc, "==", perc)])[inj_name]
        ids = db.nlargest(n_largest).index.get_level_values(STR.id).to_list()

        channel_data = pd.read_parquet(
            DATA_DIR / "channels.parquet",
            columns=inj2channels[inj_name],
            filters=[(STR.id, "in", ids), (STR.perc, "==", perc)],
        ).sort_values(by=STR.time)

        fig, ax = plt.subplot_mosaic(
            mosaic=[["distro"] * len(inj2channels[inj_name]), sorted(inj2channels[inj_name])],
            # sharex="row",
            # sharey="row",
            layout="constrained",
            figsize=(WIDTH, 0.6*WIDTH),
            height_ratios=[0.2, 0.8],
        )
        fig.suptitle(f"{INJ_NAMES[inj_name]} - HIII {perc:02d} {'F' if perc == 5 else 'M'}")
        single_box_and_rug(inj_val=inj_name, perc=perc, ax=ax["distro"])
        ax["distro"].set_xlabel("")
        for ch in inj2channels[inj_name]:
            for idx in ids:
                f = channel_data.loc[(slice(None), idx), ch]
                ax[ch].plot(f.index.get_level_values(STR.time), f, label=int(idx))
            ax[ch].grid()
            ax[ch].set_ylabel(ch)
            ax[ch].set_xlabel(STR.time)
        ax[inj2channels[inj_name][-1]].legend()
        save_fig(fig=fig, f_name=f"{inj_name}_HIII{perc:02d}_{n_largest}_largest_channels")


plot_selection()
# Out:
#   0%|          | 0/48 [00:00<?, ?it/s]2024-10-27 08:13:41,856     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:13:41,863     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:13:41,864     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:13:41,866     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:13:41,870     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:13:41,882     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:13:41,886     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:13:41,887     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 20 glyphs before
# 2024-10-27 08:13:41,892     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'c', 'e', 'f', 'five', 'h', 'hyphen', 'i', 'l', 'n', 'o', 's', 'space', 't', 'zero']
# 2024-10-27 08:13:41,893     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 44, 47, 51, 55, 56, 57, 63, 64, 65, 66, 67, 73, 78, 82, 99, 104, 106, 122]
# 2024-10-27 08:13:41,895     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 25 glyphs after
# 2024-10-27 08:13:41,896     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'five', 'h', 'hyphen', 'i', 'l', 'n', 'o', 's', 'space', 't', 'zero']
# 2024-10-27 08:13:41,898     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 44, 47, 51, 55, 56, 57, 63, 64, 65, 66, 67, 73, 78, 82, 99, 104, 106, 122, 123, 124, 125, 126, 127]
# 2024-10-27 08:13:41,899     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 25 glyphs before
# 2024-10-27 08:13:41,900     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'five', 'h', 'hyphen', 'i', 'l', 'n', 'o', 's', 'space', 't', 'zero']
# 2024-10-27 08:13:41,901     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 44, 47, 51, 55, 56, 57, 63, 64, 65, 66, 67, 73, 78, 82, 99, 104, 106, 122, 123, 124, 125, 126, 127]
# 2024-10-27 08:13:41,906     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 25 glyphs after
# 2024-10-27 08:13:41,910     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'five', 'h', 'hyphen', 'i', 'l', 'n', 'o', 's', 'space', 't', 'zero']
# 2024-10-27 08:13:41,912     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 44, 47, 51, 55, 56, 57, 63, 64, 65, 66, 67, 73, 78, 82, 99, 104, 106, 122, 123, 124, 125, 126, 127]
# 2024-10-27 08:13:41,913     INFO  MainProcess  MainThread Retaining 25 glyphs
# 2024-10-27 08:13:41,914     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:13:41,915     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:13:41,916     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:13:41,917     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:13:41,919     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:13:41,920     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:13:41,921     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:13:41,925     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:13:41,944     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:13:41,946     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:13:41,947     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:13:41,948     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:13:41,950     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:13:41,951     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:13:41,957     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:13:41,961     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:13:41,963     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:13:41,969     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:13:41,986     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:13:41,994     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:13:41,995     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:13:41,998     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:13
INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 47, 50, 52, 57, 58, 63, 66, 75, 79, 81, 83, 98, 101, 102, 105, 107, 108, 109, 116, 122]
# 2024-10-27 08:13:44,250     INFO  MainProcess  MainThread Retaining 22 glyphs
# 2024-10-27 08:13:44,251     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:13:44,252     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:13:44,253     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:13:44,254     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:13:44,256     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:13:44,257     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:13:44,259     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:13:44,264     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:13:44,277     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:13:44,278     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:13:44,279     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:13:44,280     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:13:44,281     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:13:44,282     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:13:44,290     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:13:44,291     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:13:44,293     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:13:44,296     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:13:44,331     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_virthuman_final/Chest_Deflection_HIII95_10_largest_channels
#   6%|▋         | 3/48 [00:03<00:52,  1.17s/it]2024-10-27 08:13:45,923     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:13:45,939     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:13:45,940     INFO  MainProcess  MainThread kern dropped
# 2024-10-27 08:13:45,942     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:13:45,943     INFO  MainProcess  MainThread FFTM dropped
# 2024-10-27 08:13:45,947     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:13:45,956     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:13:45,967     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 08:13:45,968     INFO  MainProcess  MainThread Added gid0 to subset
# 2024-10-27 08:13:45,969     INFO  MainProcess  MainThread Added first four glyphs to subset
# 2024-10-27 08:13:45,970     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 8 glyphs before
# 2024-10-27 08:13:45,971     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:13:45,973     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:13:45,975     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 8 glyphs after
# 2024-10-27 08:13:45,976     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:13:45,979     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:13:45,980     INFO  MainProcess  MainThread Closing glyph list over 'MATH': 8 glyphs before
# 2024-10-27 08:13:45,981     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:13:45,982     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:13:45,984     INFO  MainProcess  MainThread Closed glyph list over 'MATH': 8 glyphs after
# 2024-10-27 08:13:45,985     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:13:45,986     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:13:45,987     INFO  MainProcess  MainThread Closing glyph list over 'glyf': 8 glyphs before
# 2024-10-27 08:13:45,988     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:13:45,988     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:13:45,989     INFO  MainProcess  MainThread Closed glyph list over 'glyf': 8 glyphs after
# 2024-10-27 08:13:45,990     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:13:45,991     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:13:45,992     INFO  MainProcess  MainThread Retaining 8 glyphs
# 2024-10-27 08:13:45,994     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:13:45,995     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:13:45,996     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:13:46,000     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:13:46,012     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:13:46,017     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:13:46,018     INFO  MainProcess  MainThread fpgm subsetting not needed
# 2024-10-27 08:13:46,020     INFO  MainProcess  MainThread prep subsetting not needed
# 2024-10-27 08:13:46,021     INFO  MainProcess  MainThread cvt  subsetting not needed
# 2024-10-27 08:13:46,022     INFO  MainProcess  MainThread loca subsetting not needed
# 2024-10-27 08:13:46,023     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:13:46,024     INFO  MainProcess  MainThread gasp subsetting not needed
# 2024-10-27 08:13:46,025     INFO  MainProcess  MainThread MATH subsetted
# 2024-10-27 08:13:46,035     INFO  MainProcess  MainThread GDEF subsetted
# 2024-10-27 08:13:46,079     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:13:46,080     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:13:46,081     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:13:46,084     INFO  MainProcess  MainThread glyf subsetted
# 2024-10-27 08:13:46,085     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:13:46,086     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:13:46,087     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:13:46,088     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 08:13:46,088     INFO  MainProcess  MainThread GDEF pruned
# 2024-10-27 08:13:46,089     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:13:46,090     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:13:46,096     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:13:46,105     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:13:46,110     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:13:46,111     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:13:46,114     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:13:46,117     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:13:46,130     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:13:46,131     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:13:46,133     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 13 glyphs before
# 2024-10-27 08:13:46,133     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'F', 'H', 'I', 'e', 'five', 'h', 'hyphen', 's', 'space', 't', 'zero']
# 2024-10-27 08:13:46,135     INFO  MainProcess  MainThread Glyph IDs:   [0, 43,
INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 8 glyphs before
# 2024-10-27 08:13:48,105     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:13:48,107     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:13:48,110     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 8 glyphs after
# 2024-10-27 08:13:48,111     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:13:48,112     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:13:48,112     INFO  MainProcess  MainThread Closing glyph list over 'MATH': 8 glyphs before
# 2024-10-27 08:13:48,113     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:13:48,115     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:13:48,116     INFO  MainProcess  MainThread Closed glyph list over 'MATH': 8 glyphs after
# 2024-10-27 08:13:48,118     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:13:48,119     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:13:48,121     INFO  MainProcess  MainThread Closing glyph list over 'glyf': 8 glyphs before
# 2024-10-27 08:13:48,121     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:13:48,123     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:13:48,124     INFO  MainProcess  MainThread Closed glyph list over 'glyf': 8 glyphs after
# 2024-10-27 08:13:48,125     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'a', 'm', 'nonmarkingreturn', 's', 'space', 'three']
# 2024-10-27 08:13:48,126     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 22, 68, 80, 86]
# 2024-10-27 08:13:48,127     INFO  MainProcess  MainThread Retaining 8 glyphs
# 2024-10-27 08:13:48,129     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:13:48,130     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:13:48,131     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:13:48,132     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:13:48,145     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:13:48,150     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:13:48,151     INFO  MainProcess  MainThread fpgm subsetting not needed
# 2024-10-27 08:13:48,152     INFO  MainProcess  MainThread prep subsetting not needed
# 2024-10-27 08:13:48,153     INFO  MainProcess  MainThread cvt  subsetting not needed
# 2024-10-27 08:13:48,154     INFO  MainProcess  MainThread loca subsetting not needed
# 2024-10-27 08:13:48,155     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:13:48,156     INFO  MainProcess  MainThread gasp subsetting not needed
# 2024-10-27 08:13:48,157     INFO  MainProcess  MainThread MATH subsetted
# 2024-10-27 08:13:48,162     INFO  MainProcess  MainThread GDEF subsetted
# 2024-10-27 08:13:48,200     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:13:48,202     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:13:48,203     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:13:48,206     INFO  MainProcess  MainThread glyf subsetted
# 2024-10-27 08:13:48,207     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:13:48,208     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:13:48,209     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:13:48,210     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 08:13:48,211     INFO  MainProcess  MainThread GDEF pruned
# 2024-10-27 08:13:48,212     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:13:48,213     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:13:48,219     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:13:48,229     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:13:48,234     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:13:48,235     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:13:48,237     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:13:48,242     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:13:48,254     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:13:48,255     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:13:48,256     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 13 glyphs before
# 2024-10-27 08:13:48,257     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'H', 'I', 'M', 'e', 'five', 'h', 'hyphen', 's', 'space', 't', 'zero']
# 2024-10-27 08:13:48,259     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 51, 57, 63, 64, 65, 66, 75, 99, 104, 106, 122]
# 2024-10-27 08:13:48,260     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 13 glyphs after
# 2024-10-27 08:13:48,261     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'H', 'I', 'M', 'e', 'five', 'h', 'hyphen', 's', 'space', 't', 'zero']
# 2024-10-27 08:13:48,262     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 51, 57, 63, 64, 65, 66, 75, 99, 104, 106, 122]
# 2024-10-27 08:13:48,263     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 13 glyphs before
# 2024-10-27 08:13:48,263     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'H', 'I', 'M', 'e', 'five', 'h', 'hyphen', 's', 'space', 't', 'zero']
# 2024-10-27 08:13:48,264     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 51, 57, 63, 64, 65, 66, 75, 99, 104, 106, 122]
# 2024-10-27 08:13:48,266     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 13 glyphs after
# 2024-10-27 08:13:48,267     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'H', 'I', 'M', 'e', 'five', 'h', 'hyphen', 's', 'space', 't', 'zero']
# 2024-10-27 08:13:48,268     INFO  MainProcess  MainThread Glyph IDs:   [0, 43, 51, 57, 63, 64, 65, 66, 75, 99, 104, 106, 122]
# 2024-10-27 08:13:48,268     INFO  MainProcess  MainThread Retaining 13 glyphs
# 2024-10-27 08:13:48,269     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08
INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 40, 48, 72, 76, 81, 82, 86, 87, 91, 92]
# 2024-10-27 08:14:24,362     INFO  MainProcess  MainThread Closing glyph list over 'MATH': 15 glyphs before
# 2024-10-27 08:14:24,363     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'E', 'M', 'comma', 'e', 'i', 'n', 'nonmarkingreturn', 'o', 's', 'space', 't', 'x', 'y']
# 2024-10-27 08:14:24,366     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 40, 48, 72, 76, 81, 82, 86, 87, 91, 92]
# 2024-10-27 08:14:24,369     INFO  MainProcess  MainThread Closed glyph list over 'MATH': 15 glyphs after
# 2024-10-27 08:14:24,370     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'E', 'M', 'comma', 'e', 'i', 'n', 'nonmarkingreturn', 'o', 's', 'space', 't', 'x', 'y']
# 2024-10-27 08:14:24,371     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 40, 48, 72, 76, 81, 82, 86, 87, 91, 92]
# 2024-10-27 08:14:24,373     INFO  MainProcess  MainThread Closing glyph list over 'glyf': 15 glyphs before
# 2024-10-27 08:14:24,374     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'E', 'M', 'comma', 'e', 'i', 'n', 'nonmarkingreturn', 'o', 's', 'space', 't', 'x', 'y']
# 2024-10-27 08:14:24,375     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 40, 48, 72, 76, 81, 82, 86, 87, 91, 92]
# 2024-10-27 08:14:24,376     INFO  MainProcess  MainThread Closed glyph list over 'glyf': 15 glyphs after
# 2024-10-27 08:14:24,378     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'E', 'M', 'comma', 'e', 'i', 'n', 'nonmarkingreturn', 'o', 's', 'space', 't', 'x', 'y']
# 2024-10-27 08:14:24,379     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 40, 48, 72, 76, 81, 82, 86, 87, 91, 92]
# 2024-10-27 08:14:24,380     INFO  MainProcess  MainThread Retaining 15 glyphs
# 2024-10-27 08:14:24,382     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:14:24,384     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:14:24,384     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:14:24,385     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:14:24,396     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:14:24,401     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:14:24,402     INFO  MainProcess  MainThread fpgm subsetting not needed
# 2024-10-27 08:14:24,403     INFO  MainProcess  MainThread prep subsetting not needed
# 2024-10-27 08:14:24,404     INFO  MainProcess  MainThread cvt  subsetting not needed
# 2024-10-27 08:14:24,405     INFO  MainProcess  MainThread loca subsetting not needed
# 2024-10-27 08:14:24,406     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:14:24,407     INFO  MainProcess  MainThread gasp subsetting not needed
# 2024-10-27 08:14:24,412     INFO  MainProcess  MainThread MATH subsetted
# 2024-10-27 08:14:24,417     INFO  MainProcess  MainThread GDEF subsetted
# 2024-10-27 08:14:24,473     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:14:24,480     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:14:24,481     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:14:24,484     INFO  MainProcess  MainThread glyf subsetted
# 2024-10-27 08:14:24,486     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:14:24,487     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:14:24,491     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:14:24,492     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 08:14:24,494     INFO  MainProcess  MainThread GDEF pruned
# 2024-10-27 08:14:24,496     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:24,497     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:24,502     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:14:24,513     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:14:24,520     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:14:24,522     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:14:24,524     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:14:24,529     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:24,540     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:24,542     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:14:24,543     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 12 glyphs before
# 2024-10-27 08:14:24,544     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'H', 'I', 'M', 'N', 'c', 'e', 'five', 'hyphen', 'k', 'nine', 'space']
# 2024-10-27 08:14:24,545     INFO  MainProcess  MainThread Glyph IDs:   [0, 44, 51, 57, 63, 65, 66, 71, 75, 77, 79, 104]
# 2024-10-27 08:14:24,546     INFO  MainProcess  MainThread Closed glyph list over 'GSUB':
INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:24,792     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:14:24,819     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_virthuman_final/Neck_My_Extension_HIII95_10_largest_channels
# 100%|██████████| 48/48 [00:44<00:00,  1.09it/s]

# %%
DROPPED_IDS: Dict[int, List[int]] = {
    5: [7, 16, 25, 88, 169, 206, 232],
    50: [],
    95: [],
}
json_util.dump(obj=DROPPED_IDS, f_path=DATA_DIR / STR.fname_dropped_ids)
DROPPED_IDS
# Out:
# {5: [7, 16, 25, 88, 169, 206, 232], 50: [], 95: []}

# %%
def box_and_rug_cleaned():
    percs = [5, 50, 95]
    inj_names = INJURIES

    fig_width: float = WIDTH
    fig_height: float = 1.35*WIDTH

    fig, ax = plt.subplots(
        nrows=len(inj_names),
        ncols=len(percs),
        layout="constrained",
        figsize=(fig_width, fig_height),
    )

    # plot
    versions = list(product(list(enumerate(inj_names)), list(enumerate(percs))))
    for (row, inj_val), (col, perc) in tqdm(versions):
        single_box_and_rug(inj_val=inj_val, perc=perc, ax=ax[row, col], drop_ids=DROPPED_IDS)
        ax[row, 0].set_ylabel(INJ_NAMES[inj_val])
        ax[row, col].set_xlabel("")
        ax[0, col].set_title(f"HIII {perc:02d} {'F' if perc == 5 else 'M'}")

    save_fig(fig=fig, f_name="injury_criteria_box_and_rug_cleaned")


box_and_rug_cleaned()
# Out:
# 100%|██████████| 27/27 [00:03<00:00,  8.61it/s]
# 2024-10-27 08:14:32,362     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:14:32,416     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:14:32,418     INFO  MainProcess  MainThread kern dropped
# 2024-10-27 08:14:32,428     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:14:32,429     INFO  MainProcess  MainThread FFTM dropped
# 2024-10-27 08:14:32,433     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:32,458     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:32,472     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 08:14:32,485     INFO  MainProcess  MainThread Added gid0 to subset
# 2024-10-27 08:14:32,488     INFO  MainProcess  MainThread Added first four glyphs to subset
# 2024-10-27 08:14:32,489     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 30 glyphs before
# 2024-10-27 08:14:32,490     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 08:14:32,493     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 08:14:32,502     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 30 glyphs after
# 2024-10-27 08:14:32,503     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 08:14:32,504     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 08:14:32,506     INFO  MainProcess  MainThread Closing glyph list over 'MATH': 30 glyphs before
# 2024-10-27 08:14:32,507     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 08:14:32,509     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 08:14:32,511     INFO  MainProcess  MainThread Closed glyph list over 'MATH': 30 glyphs after
# 2024-10-27 08:14:32,513     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 08:14:32,514     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 08:14:32,515     INFO  MainProcess  MainThread Closing glyph list over 'glyf': 30 glyphs before
# 2024-10-27 08:14:32,517     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 08:14:32,518     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 08:14:32,519     INFO  MainProcess  MainThread Closed glyph list over 'glyf': 30 glyphs after
# 2024-10-27 08:14:32,524     INFO  MainProcess  MainThread Glyph names: ['.notdef', '.null', 'C', 'E', 'F', 'H', 'I', 'M', 'S', 'T', 'a', 'comma', 'e', 'five', 'h', 'i', 'm', 'n', 'nonmarkingreturn', 'o', 'one', 'p', 'r', 's', 'space', 't', 'three', 'x', 'y', 'z']
# 2024-10-27 08:14:32,525     INFO  MainProcess  MainThread Glyph IDs:   [0, 1, 2, 3, 15, 20, 22, 24, 38, 40, 41, 43, 44, 48, 54, 55, 68, 72, 75, 76, 80, 81, 82, 83, 85, 86, 87, 91, 92, 93]
# 2024-10-27 08:14:32,531     INFO  MainProcess  MainThread Retaining 30 glyphs
# 2024-10-27 08:14:32,545     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:14:32,553     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:14:32,555     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:14:32,556     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:14:32,568     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:14:32,578     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:14:32,580     INFO  MainProcess  MainThread fpgm subsetting not needed
# 2024-10-27 08:14:32,581     INFO  MainProcess  MainThread prep subsetting not needed
# 2024-10-27 08:14:32,582     INFO  MainProcess  MainThread cvt  subsetting not needed
# 2024-10-27 08:14:32,583     INFO  MainProcess  MainThread loca subsetting not needed
# 2024-10-27 08:14:32,584     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:14:32,585     INFO  MainProcess  MainThread gasp subsetting not needed
# 2024-10-27 08:14:32,586     INFO  MainProcess  MainThread MATH subsetted
# 2024-10-27 08:14:32,591     INFO  MainProcess  MainThread GDEF subsetted
# 2024-10-27 08:14:32,645     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:14:32,649     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:14:32,650     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:14:32,654     INFO  MainProcess  MainThread glyf subsetted
# 2024-10-27 08:14:32,655     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:14:32,657     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:14:32,658     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:14:32,659     INFO  MainProcess  MainThread glyf pruned
# 2024-10-27 08:14:32,660     INFO  MainProcess  MainThread GDEF pruned
# 2024-10-27 08:14:32,661     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:32,662     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:32,673     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:14:32,689     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:14:32,695     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:14:32,696     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:14:32,699     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:14:32,704     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:32,722     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:32,728     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:14:32,730     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 37 glyphs before
# 2024-10-27 08:14:32,731     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'M', 'N', 'V', 'a', 'c', 'd', 'e', 'eight', 'f', 'five', 'four', 'h', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'zero']
# 2024-10-27 08:14:32,732     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 51, 52, 55, 56, 57, 58, 63, 64, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 89, 97, 99, 101, 102, 104, 106, 107, 108, 110, 112, 122]
# 2024-10-27 08:14:32,734     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 43 glyphs after
# 2024-10-27 08:14:32,735     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'M', 'N', 'V', 'a', 'c', 'd', 'e', 'eight', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'h', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'zero']
# 2024-10-27 08:14:32,736     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 51, 52, 55, 56, 57, 58, 63, 64, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 89, 97, 99, 101, 102, 104, 106, 107, 108, 110, 112, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:14:32,747     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 43 glyphs before
# 2024-10-27 08:14:32,749     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'M', 'N', 'V', 'a', 'c', 'd', 'e', 'eight', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'h', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'zero']
# 2024-10-27 08:14:32,750     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 51, 52, 55, 56, 57, 58, 63, 64, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 89, 97, 99, 101, 102, 104, 106, 107, 108, 110, 112, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:14:32,758     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 43 glyphs after
# 2024-10-27 08:14:32,759     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'F', 'H', 'I', 'M', 'N', 'V', 'a', 'c', 'd', 'e', 'eight', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'h', 'i', 'k', 'l', 'm', 'n', 'nine', 'o', 'one', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'zero']
# 2024-10-27 08:14:32,759     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 47, 48, 51, 52, 55, 56, 57, 58, 63, 64, 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 89, 97, 99, 101, 102, 104, 106, 107, 108, 110, 112, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:14:32,760     INFO  MainProcess  MainThread Retaining 43 glyphs
# 2024-10-27 08:14:32,761     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:14:32,764     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:14:32,765     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:14:32,766     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:14:32,767     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:14:32,768     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:14:32,771     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:14:32,773     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:14:32,789     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:14:32,790     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:14:32,791     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:14:32,794     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:14:32,795     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:14:32,796     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:14:32,803     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:14:32,805     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:32,807     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:32,813     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:14:32,967     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_virthuman_final/injury_criteria_box_and_rug_cleaned

# %%
def plot_dropped_grid():
    # get data
    doe = pd.read_parquet(DOE_FPATH)
    factors = sorted(doe.columns)

    # plot
    fig, ax = plt.subplots(
        ncols=doe.shape[1],
        nrows=doe.shape[1] + 1,
        figsize=(WIDTH, WIDTH),
        sharex="col",
        sharey="row",
        layout="constrained",
        height_ratios=[0.1] + [1] * doe.shape[1],
    )
    gs = ax[0, 0].get_gridspec()
    for a in ax[0]:
        a.remove()
    axbig = fig.add_subplot(gs[0, :])
    axbig.axis("off")

    for i, x_axis in enumerate(factors):
        for j, y_axis in enumerate(factors):
            ax[i + 1, j].scatter(doe[y_axis], doe[x_axis], color="b", label="DoE", s=0.05)

            for q, perc in enumerate(DROPPED_IDS.keys()):
                ax[i + 1, j].scatter(
                    doe.loc[DROPPED_IDS[perc], y_axis],
                    doe.loc[DROPPED_IDS[perc], x_axis],
                    color="r",
                    label=f"Dropped VH{perc:02d}{'F' if perc == 5 else 'M'}  n={len(DROPPED_IDS[perc])}",
                    marker=["+", "x", "*"][q],
                )
            ax[i + 1, j].grid()
            ax[i + 1, j].set_axisbelow(True)

    for i, label in enumerate(factors):
        ax[-1, i].set_xlabel(label)
        ax[i + 1, 0].set_ylabel(label)
    axbig.legend(*ax[-1, -1].get_legend_handles_labels(), ncols=4, loc="center")

    save_fig(fig=fig, f_name="doe_dropped_ids")


plot_dropped_grid()
# Out:
# 2024-10-27 08:14:38,939     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:14:38,946     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:14:38,947     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:14:38,949     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:14:38,953     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:38,963     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:38,965     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:14:38,966     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 33 glyphs before
# 2024-10-27 08:14:38,967     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'B', 'C', 'D', 'E', 'F', 'H', 'L', 'M', 'N', 'P', 'S', 'T', 'V', 'd', 'e', 'eight', 'equal', 'five', 'four', 'minus', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 'seven', 'space', 'two', 'zero']
# 2024-10-27 08:14:38,968     INFO  MainProcess  MainThread Glyph IDs:   [0, 28, 35, 43, 47, 48, 50, 51, 52, 53, 55, 57, 58, 63, 72, 75, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 101, 104, 105, 108, 112, 122, 419]
# 2024-10-27 08:14:38,971     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 33 glyphs after
# 2024-10-27 08:14:38,971     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'B', 'C', 'D', 'E', 'F', 'H', 'L', 'M', 'N', 'P', 'S', 'T', 'V', 'd', 'e', 'eight', 'equal', 'five', 'four', 'minus', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 'seven', 'space', 'two', 'zero']
# 2024-10-27 08:14:38,972     INFO  MainProcess  MainThread Glyph IDs:   [0, 28, 35, 43, 47, 48, 50, 51, 52, 53, 55, 57, 58, 63, 72, 75, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 101, 104, 105, 108, 112, 122, 419]
# 2024-10-27 08:14:38,973     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 33 glyphs before
# 2024-10-27 08:14:38,974     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'B', 'C', 'D', 'E', 'F', 'H', 'L', 'M', 'N', 'P', 'S', 'T', 'V', 'd', 'e', 'eight', 'equal', 'five', 'four', 'minus', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 'seven', 'space', 'two', 'zero']
# 2024-10-27 08:14:38,975     INFO  MainProcess  MainThread Glyph IDs:   [0, 28, 35, 43, 47, 48, 50, 51, 52, 53, 55, 57, 58, 63, 72, 75, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 101, 104, 105, 108, 112, 122, 419]
# 2024-10-27 08:14:38,985     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 33 glyphs after
# 2024-10-27 08:14:38,986     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'A', 'B', 'C', 'D', 'E', 'F', 'H', 'L', 'M', 'N', 'P', 'S', 'T', 'V', 'd', 'e', 'eight', 'equal', 'five', 'four', 'minus', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 'seven', 'space', 'two', 'zero']
# 2024-10-27 08:14:38,988     INFO  MainProcess  MainThread Glyph IDs:   [0, 28, 35, 43, 47, 48, 50, 51, 52, 53, 55, 57, 58, 63, 72, 75, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 101, 104, 105, 108, 112, 122, 419]
# 2024-10-27 08:14:38,990     INFO  MainProcess  MainThread Retaining 33 glyphs
# 2024-10-27 08:14:38,991     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:14:38,992     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:14:38,993     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:14:38,994     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:14:38,995     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:14:38,996     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:14:38,998     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:14:39,000     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:14:39,022     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:14:39,025     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:14:39,026     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:14:39,028     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:14:39,030     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:14:39,031     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:14:39,038     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:14:39,040     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:39,042     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:39,052     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:14:39,090     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_virthuman_final/doe_dropped_ids

# %%
def plot_bars(point_db: pd.DataFrame, fig_title: str, store: bool = True, sort_by_all: bool = True) -> None:
    if sort_by_all:
        existing_points = [str(x) for x in sorted(set(point_db.to_numpy().flatten()))]
    percs = sorted(point_db.index.get_level_values(STR.perc).unique())
    for perc in percs:
        for idx in DROPPED_IDS[perc]:
            try:
                point_db.drop(index=[idx, perc], inplace=True)
            except KeyError:
                LOG.warning("Could not drop index %s of perc %s", idx, perc)

    fig_width: float = WIDTH
    fig_height: float = 0.7 * fig_width
    fig, ax = plt.subplots(
        ncols=point_db.shape[1],
        nrows=len(percs),
        figsize=(fig_width, fig_height),
        sharex=True,
        sharey=True if sort_by_all else "row",
        layout="constrained",
    )
    fig.suptitle(fig_title)
    vers = list(product(list(enumerate(point_db.columns)), list(enumerate(percs))))
    for (col, val), (row, perc) in vers:
        if not sort_by_all:
            existing_points = [
                str(x)
                for x in sorted(
                    set(point_db.loc[(slice(None), perc), val].to_numpy().flatten()), key=lambda x: int(x.split(":")[0])
                )
            ]
        cnt = [str(x) for x in point_db.loc[(slice(None), perc), val].to_list()]
        sns.countplot(
            cnt,
            ax=ax[row, col],
            order=existing_points,
            alpha=0.5,
            native_scale=False,
        )
        ax[0, col].set_title(val, size="x-small")
        ax[row, 0].set_ylabel(f"HIII{perc:02} - n={len(cnt)}")
        ax[row, col].set_xlim([0, 9000])
        ax[row, col].bar_label(ax[row, col].containers[0], fontsize=7, rotation=90, padding=2)
    if store:
        save_fig(fig=fig, f_name=f"{'_'.join(fig_title.lower().split())}_distribution_bars")


plot_bars(
    point_db=pd.concat(
        [LoadForClassification(data_directory=DATA_DIR).injury_value_to_points(percentile=perc) for perc in (5, 95)], axis=0
    ),
    fig_title="Points by Euro NCAP",
    store=True,
)
# Out:
# 2024-10-27 08:14:39,125     INFO  MainProcess  MainThread Directory '/root/py_projects/aihiii/data/doe/virthuman' exists
# 2024-10-27 08:14:39,126     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/virthuman/injury_criteria.parquet' exists
# 2024-10-27 08:14:39,127     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/virthuman/results_info.json' exists
# 2024-10-27 08:14:39,134     INFO  MainProcess  MainThread Hashes of injury files are the same
# 2024-10-27 08:14:39,481     INFO  MainProcess  MainThread Directory '/root/py_projects/aihiii/data/doe/virthuman' exists
# 2024-10-27 08:14:39,482     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/virthuman/injury_criteria.parquet' exists
# 2024-10-27 08:14:39,483     INFO  MainProcess  MainThread File '/root/py_projects/aihiii/data/doe/virthuman/results_info.json' exists
# 2024-10-27 08:14:39,486     INFO  MainProcess  MainThread Hashes of injury files are the same
# /tmp/ipykernel_3460809/2904456802.py:8: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   point_db.drop(index=[idx, perc], inplace=True)
# 2024-10-27 08:14:39,765  WARNING  MainProcess  MainThread Could not drop index 16 of perc 5
# 2024-10-27 08:14:39,766  WARNING  MainProcess  MainThread Could not drop index 25 of perc 5
# 2024-10-27 08:14:39,767  WARNING  MainProcess  MainThread Could not drop index 88 of perc 5
# 2024-10-27 08:14:39,769  WARNING  MainProcess  MainThread Could not drop index 169 of perc 5
# 2024-10-27 08:14:39,771  WARNING  MainProcess  MainThread Could not drop index 206 of perc 5
# 2024-10-27 08:14:39,773  WARNING  MainProcess  MainThread Could not drop index 232 of perc 5
# 2024-10-27 08:14:40,083     INFO  MainProcess  MainThread Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-27 08:14
 66, 67, 71, 73, 75, 76, 77, 78, 79, 82, 83, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:14:45,662     INFO  MainProcess  MainThread Retaining 53 glyphs
# 2024-10-27 08:14:45,663     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:14:45,664     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:14:45,664     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:14:45,665     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:14:45,666     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:14:45,667     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:14:45,667     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:14:45,669     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:14:45,707     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:14:45,711     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:14:45,712     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:14:45,715     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:14:45,716     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:14:45,717     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:14:45,735     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:14:45,737     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:45,739     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:45,769     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:14:45,822     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_virthuman_final/points_by_euro_ncap_distribution_bars

# %%
def plot_classes(n_classes: int):
    LOG.info("Plotting classes with %s classes", n_classes)
    db = pd.read_parquet(CLASSES_FPATHS[n_classes])
    db = pd.concat([db.loc[(slice(None), perc), :].replace(RENAMER[perc][n_classes]) for perc in (5, 95)], axis=0)

    plot_bars(point_db=db, fig_title=f"Classification with {n_classes} Classes", store=True, sort_by_all=False)


_ = [plot_classes(n_classes=n_classes) for n_classes in CLASSES_FPATHS.keys()]
# Out:
# 2024-10-27 08:14:45,844     INFO  MainProcess  MainThread Plotting classes with 2 classes
# /tmp/ipykernel_3460809/2904456802.py:8: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   point_db.drop(index=[idx, perc], inplace=True)
# 2024-10-27 08:14:45,891  WARNING  MainProcess  MainThread Could not drop index 16 of perc 5
# 2024-10-27 08:14:45,892  WARNING  MainProcess  MainThread Could not drop index 25 of perc 5
# 2024-10-27 08:14:45,894  WARNING  MainProcess  MainThread Could not drop index 88 of perc 5
# 2024-10-27 08:14:45,895  WARNING  MainProcess  MainThread Could not drop index 169 of perc 5
# 2024-10-27 08:14:45,896  WARNING  MainProcess  MainThread Could not drop index 206 of perc 5
# 2024-10-27 08:14:45,897  WARNING  MainProcess  MainThread Could not drop index 232 of perc 5
# 2024-10-27 08:14:49,237     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:14:49,244     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:14:49,247     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:14:49,251     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:14:49,256     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:49,286     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:49,315     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:14:49,316     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 16 glyphs before
# 2024-10-27 08:14:49,317     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'h', 'i', 'l', 'n', 'o', 's', 'space', 't', 'two', 'w']
# 2024-10-27 08:14:49,319     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 104, 106, 108, 115]
# 2024-10-27 08:14:49,325     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 21 glyphs after
# 2024-10-27 08:14:49,328     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'space', 't', 'two', 'w']
# 2024-10-27 08:14:49,329     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 104, 106, 108, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:14:49,330     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 21 glyphs before
# 2024-10-27 08:14:49,333     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'space', 't', 'two', 'w']
# 2024-10-27 08:14:49,334     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 104, 106, 108, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:14:49,339     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 21 glyphs after
# 2024-10-27 08:14:49,341     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'space', 't', 'two', 'w']
# 2024-10-27 08:14:49,342     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 104, 106, 108, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:14:49,344     INFO  MainProcess  MainThread Retaining 21 glyphs
# 2024-10-27 08:14:49,352     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:14:49,355     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:14:49,358     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:14:49,359     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:14:49,361     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:14:49,362     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:14:49,364     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:14:49,369     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:14:49,380     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:14:49,382     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:14:49,383     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:14:49,384     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:14:49,386     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:14:49,387     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:14:49,402     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:14:49,404     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:49,406     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:49,413     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:14:49,431     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:14:49,442     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:14:49,448     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:14:49,451     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:14:49,455     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:49,490     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:49,491     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:14:49,493     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 50 glyphs before
# 2024-10-27 08:14:49,493     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:14:49,500     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122]
# 2024-10-27 08:14:49,503     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 56 glyphs after
# 2024-10-27 08:14:49,505     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:14:49,516     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:14:49,518     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 56 glyphs before
# 2024-10-27 08:14:49,518     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:14:49,520     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:14:49,529     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 56 glyphs after
# 2024-10-27 08:14:49,534     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:14:49,535     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:14:49,537     INFO  MainProcess  MainThread Retaining 56 glyphs
# 2024-10-27 08:14:49,539     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:14:49,540     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:14:49,542     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:14:49,544     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:14:49,546     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:14:49,547     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:14:49,549     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:14:49,553     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:14:49,592     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:14:49,593     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:14:49,595     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:14:49,597     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:14:49,598     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:14:49,599     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:14:49,608     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:14:49,609     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:49,611     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:49,629     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:14:49,664     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_virthuman_final/classification_with_2_classes_distribution_bars
# 2024-10-27 08:14:49,666     INFO  MainProcess  MainThread Plotting classes with 3 classes
# /tmp/ipykernel_3460809/2904456802.py:8: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   point_db.drop(index=[idx, perc], inplace=True)
# 2024-10-27 08:14:49,690  WARNING  MainProcess  MainThread Could not drop index 16 of perc 5
# 2024-10-27 08:14:49,692  WARNING  MainProcess  MainThread Could not drop index 25 of perc 5
# 2024-10-27 08:14:49,693  WARNING  MainProcess  MainThread Could not drop index 88 of perc 5
# 2024-10-27 08:14:49,694  WARNING  MainProcess  MainThread Could not drop index 169 of perc 5
# 2024-10-27 08:14:49,695  WARNING  MainProcess  MainThread Could not drop index 206 of perc 5
# 2024-10-27 08:14:49,698  WARNING  MainProcess  MainThread Could not drop index 232 of perc 5
# 2024-10-27 08:14:53,965     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:14:53,983     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:14:53,985     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:14:53,987     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:14:53,992     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:54,007     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:54,008     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:14:54,009     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 16 glyphs before
# 2024-10-27 08:14:54,010     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'h', 'i', 'l', 'n', 'o', 's', 'space', 't', 'three', 'w']
# 2024-10-27 08:14:54,012     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 104, 106, 107, 115]
# 2024-10-27 08:14:54,014     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 21 glyphs after
# 2024-10-27 08:14:54,015     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'space', 't', 'three', 'w']
# 2024-10-27 08:14:54,016     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 104, 106, 107, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:14:54,017     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 21 glyphs before
# 2024-10-27 08:14:54,018     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'space', 't', 'three', 'w']
# 2024-10-27 08:14:54,019     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 104, 106, 107, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:14:54,039     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 21 glyphs after
# 2024-10-27 08:14:54,040     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'space', 't', 'three', 'w']
# 2024-10-27 08:14:54,044     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 104, 106, 107, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:14:54,045     INFO  MainProcess  MainThread Retaining 21 glyphs
# 2024-10-27 08:14:54,047     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:14:54,049     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:14:54,050     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:14:54,051     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:14:54,052     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:14:54,053     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:14:54,055     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:14:54,057     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:14:54,070     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:14:54,072     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:14:54,073     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:14:54,076     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:14:54,078     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:14:54,079     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:14:54,085     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:14:54,087     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:54,091     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:54,109     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:14:54,141     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:14:54,152     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:14:54,154     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:14:54,156     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:14:54,163     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:14:54,176     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:14:54,180     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:14:54,181     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 51 glyphs before
# 2024-10-27 08:14:54,183     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:14:54,185     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122]
# 2024-10-27 08:14:54,188     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 57 glyphs after
# 2024-10-27 08:14:54,190     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:14:54,195     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:14:54,196     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 57 glyphs before
# 2024-10-27 08:14:54,199     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:14:54,201     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:14:54,213     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 57 glyphs after
# 2024-10-27 08:14:54,217     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:14:54,218     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:14:54,219     INFO  MainProcess  MainThread Retaining 57 glyphs
# 2024-10-27 08:14:54,220     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:14:54,221     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:14:54,222     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:14:54,223     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:14:54,226     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:14:54,228     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08
INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:14:57,446     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_virthuman_final/classification_with_5_classes_distribution_bars
# 2024-10-27 08:14:57,447     INFO  MainProcess  MainThread Plotting classes with 7 classes
# /tmp/ipykernel_3460809/2904456802.py:8: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   point_db.drop(index=[idx, perc], inplace=True)
# 2024-10-27 08:14:57,470  WARNING  MainProcess  MainThread Could not drop index 16 of perc 5
# 2024-10-27 08:14:57,471  WARNING  MainProcess  MainThread Could not drop index 25 of perc 5
# 2024-10-27 08:14:57,472  WARNING  MainProcess  MainThread Could not drop index 88 of perc 5
# 2024-10-27 08:14:57,473  WARNING  MainProcess  MainThread Could not drop index 169 of perc 5
# 2024-10-27 08:14:57,474  WARNING  MainProcess  MainThread Could not drop index 206 of perc 5
# 2024-10-27 08:14:57,475  WARNING  MainProcess  MainThread Could not drop index 232 of perc 5
# 2024-10-27 08:15:00,371     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:15:00,376     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:15:00,377     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:15:00,378     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:15:00,381     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:00,390     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:00,392     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:15:00,393     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 16 glyphs before
# 2024-10-27 08:15:00,394     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'h', 'i', 'l', 'n', 'o', 's', 'seven', 'space', 't', 'w']
# 2024-10-27 08:15:00,397     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 101, 104, 106, 115]
# 2024-10-27 08:15:00,399     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 21 glyphs after
# 2024-10-27 08:15:00,400     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'seven', 'space', 't', 'w']
# 2024-10-27 08:15:00,402     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 101, 104, 106, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:15:00,402     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 21 glyphs before
# 2024-10-27 08:15:00,403     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'seven', 'space', 't', 'w']
# 2024-10-27 08:15:00,404     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 101, 104, 106, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:15:00,410     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 21 glyphs after
# 2024-10-27 08:15:00,411     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'a', 'c', 'e', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_l', 'h', 'i', 'l', 'n', 'o', 's', 'seven', 'space', 't', 'w']
# 2024-10-27 08:15:00,412     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 51, 56, 64, 67, 73, 78, 82, 99, 101, 104, 106, 115, 123, 124, 125, 126, 127]
# 2024-10-27 08:15:00,413     INFO  MainProcess  MainThread Retaining 21 glyphs
# 2024-10-27 08:15:00,414     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:15:00,415     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:15:00,417     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:15:00,418     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:15:00,420     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:15:00,421     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:15:00,422     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:15:00,425     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:15:00,433     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:15:00,435     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:15:00,437     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:15:00,438     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:15:00,439     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:15:00,441     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:15:00,445     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:15:00,446     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:00,448     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:00,451     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:15:00,466     INFO  MainProcess  MainThread maxp pruned
# 2024-10-27 08:15:00,472     INFO  MainProcess  MainThread cmap pruned
# 2024-10-27 08:15:00,473     INFO  MainProcess  MainThread post pruned
# 2024-10-27 08:15:00,476     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:15:00,480     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:00,490     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:00,491     INFO  MainProcess  MainThread Added .notdef to subset
# 2024-10-27 08:15:00,493     INFO  MainProcess  MainThread Closing glyph list over 'GSUB': 51 glyphs before
# 2024-10-27 08:15:00,494     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:15:00,495     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122]
# 2024-10-27 08:15:00,497     INFO  MainProcess  MainThread Closed glyph list over 'GSUB': 57 glyphs after
# 2024-10-27 08:15:00,498     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:15:00,499     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:15:00,500     INFO  MainProcess  MainThread Closing glyph list over 'CFF ': 57 glyphs before
# 2024-10-27 08:15:00,500     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:15:00,501     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:15:00,509     INFO  MainProcess  MainThread Closed glyph list over 'CFF ': 57 glyphs after
# 2024-10-27 08:15:00,511     INFO  MainProcess  MainThread Glyph names: ['.notdef', 'C', 'D', 'E', 'F', 'H', 'I', 'M', 'N', 'P', 'S', 'T', 'V', 'a', 'c', 'colon', 'd', 'e', 'eight', 'equal', 'f', 'f_f', 'f_f_i', 'f_f_l', 'f_i', 'f_k', 'f_l', 'five', 'four', 'greater', 'h', 'hyphen', 'i', 'k', 'l', 'less', 'm', 'n', 'nine', 'o', 'one', 'p', 'period', 'r', 's', 'seven', 'six', 'space', 't', 'three', 'two', 'u', 'underscore', 'x', 'y', 'z', 'zero']
# 2024-10-27 08:15:00,512     INFO  MainProcess  MainThread Glyph IDs:   [0, 29, 43, 44, 45, 47, 48, 50, 51, 52, 53, 55, 56, 57, 58, 62, 63, 64, 65, 66, 67, 71, 73, 74, 75, 76, 77, 78, 79, 82, 83, 84, 85, 89, 97, 98, 99, 101, 102, 104, 105, 106, 107, 108, 110, 111, 112, 117, 119, 121, 122, 123, 124, 125, 126, 127, 793]
# 2024-10-27 08:15:00,513     INFO  MainProcess  MainThread Retaining 57 glyphs
# 2024-10-27 08:15:00,514     INFO  MainProcess  MainThread head subsetting not needed
# 2024-10-27 08:15:00,515     INFO  MainProcess  MainThread hhea subsetting not needed
# 2024-10-27 08:15:00,515     INFO  MainProcess  MainThread maxp subsetting not needed
# 2024-10-27 08:15:00,516     INFO  MainProcess  MainThread OS/2 subsetting not needed
# 2024-10-27 08:15:00,517     INFO  MainProcess  MainThread cmap subsetted
# 2024-10-27 08:15:00,518     INFO  MainProcess  MainThread post subsetted
# 2024-10-27 08:15:00,519     INFO  MainProcess  MainThread CFF  subsetted
# 2024-10-27 08:15:00,527     INFO  MainProcess  MainThread hmtx subsetted
# 2024-10-27 08:15:00,550     INFO  MainProcess  MainThread GPOS subsetted
# 2024-10-27 08:15:00,551     INFO  MainProcess  MainThread GSUB subsetted
# 2024-10-27 08:15:00,552     INFO  MainProcess  MainThread name subsetting not needed
# 2024-10-27 08:15:00,553     INFO  MainProcess  MainThread head pruned
# 2024-10-27 08:15:00,554     INFO  MainProcess  MainThread OS/2 Unicode ranges pruned: [0]
# 2024-10-27 08:15:00,555     INFO  MainProcess  MainThread OS/2 CodePage ranges pruned: [0]
# 2024-10-27 08:15:00,563     INFO  MainProcess  MainThread CFF  pruned
# 2024-10-27 08:15:00,565     INFO  MainProcess  MainThread GPOS pruned
# 2024-10-27 08:15:00,566     INFO  MainProcess  MainThread GSUB pruned
# 2024-10-27 08:15:00,578     INFO  MainProcess  MainThread name pruned
# 2024-10-27 08:15:00,608     INFO  MainProcess  MainThread Saved figure to /root/py_projects/aihiii/reports/figures/analyze_injury_data_virthuman_final/classification_with_7_classes_distribution_bars
